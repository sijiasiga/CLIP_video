# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_0.1_frame9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 112 (delta 54), reused 49 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 1.39 MiB | 29.62 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.2 (from boto3)
#   Downloading botocore-1.38.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 8.4 MB/s eta 0:00:00
# Downloading botocore-1.38.2-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 122.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.5 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.2 botocore-1.38.2 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.1, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.1)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 900
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA A100-SXM4-40GB

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-24 19:38:20--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.59, 2620:1ec:bdf::59
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt’
#
# ViT-B-32.pt         100%[===================>] 337.58M  57.9MB/s    in 5.1s
#
# 2025-04-24 19:38:25 (65.6 MB/s) - ‘./modules/ViT-B-32.pt’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=4ce2b0d40385bdfe2030880042a35fc65769faafbde352e2b6cabc38442f47c0
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
  --do_train \
  --num_thread_reader 8 \
  --epochs 5 \
  --batch_size 64 \
  --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
  --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
  --data_path  "$DATA_PATH"/MSRVTT_data.json \
  --features_path "$VIDEO_PATH" \
  --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
  --lr 1e-4 \
  --max_words 32 \
  --max_frames 8 \
  --batch_size_val 8 \
  --datatype msrvtt \
  --expand_msrvtt_sentences \
  --feature_framerate 1 \
  --coef_lr 1e-3 \
  --freeze_layer_num 6 \
  --slice_framepos 9 \
  --loose_type \
  --linear_patch 2d \
  --sim_header meanP \
  --pretrained_clip_name ViT-B/32 \
  --fp16 \
  --fp16_opt_level O1
# Out:
# 04/24/2025 19:39:00 - INFO -   Effective parameters:
# 04/24/2025 19:39:00 - INFO -     <<< batch_size: 64
# 04/24/2025 19:39:00 - INFO -     <<< batch_size_val: 8
# 04/24/2025 19:39:00 - INFO -     <<< cache_dir:
# 04/24/2025 19:39:00 - INFO -     <<< coef_lr: 0.001
# 04/24/2025 19:39:00 - INFO -     <<< cross_model: cross-base
# 04/24/2025 19:39:00 - INFO -     <<< cross_num_hidden_layers: 4
# 04/24/2025 19:39:00 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/24/2025 19:39:00 - INFO -     <<< datatype: msrvtt
# 04/24/2025 19:39:00 - INFO -     <<< do_eval: False
# 04/24/2025 19:39:00 - INFO -     <<< do_lower_case: False
# 04/24/2025 19:39:00 - INFO -     <<< do_pretrain: False
# 04/24/2025 19:39:00 - INFO -     <<< do_train: True
# 04/24/2025 19:39:00 - INFO -     <<< epochs: 5
# 04/24/2025 19:39:00 - INFO -     <<< eval_frame_order: 0
# 04/24/2025 19:39:00 - INFO -     <<< expand_msrvtt_sentences: True
# 04/24/2025 19:39:00 - INFO -     <<< feature_framerate: 1
# 04/24/2025 19:39:00 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/24/2025 19:39:00 - INFO -     <<< fp16: True
# 04/24/2025 19:39:00 - INFO -     <<< fp16_opt_level: O1
# 04/24/2025 19:39:00 - INFO -     <<< freeze_layer_num: 6
# 04/24/2025 19:39:00 - INFO -     <<< gradient_accumulation_steps: 1
# 04/24/2025 19:39:00 - INFO -     <<< hard_negative_rate: 0.5
# 04/24/2025 19:39:00 - INFO -     <<< init_model: None
# 04/24/2025 19:39:00 - INFO -     <<< linear_patch: 2d
# 04/24/2025 19:39:00 - INFO -     <<< loose_type: True
# 04/24/2025 19:39:00 - INFO -     <<< lr: 0.0001
# 04/24/2025 19:39:00 - INFO -     <<< lr_decay: 0.9
# 04/24/2025 19:39:00 - INFO -     <<< margin: 0.1
# 04/24/2025 19:39:00 - INFO -     <<< max_frames: 8
# 04/24/2025 19:39:00 - INFO -     <<< max_words: 32
# 04/24/2025 19:39:00 - INFO -     <<< n_display: 100
# 04/24/2025 19:39:00 - INFO -     <<< n_gpu: 1
# 04/24/2025 19:39:00 - INFO -     <<< n_pair: 1
# 04/24/2025 19:39:00 - INFO -     <<< negative_weighting: 1
# 04/24/2025 19:39:00 - INFO -     <<< num_thread_reader: 8
# 04/24/2025 19:39:00 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/24/2025 19:39:00 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/24/2025 19:39:00 - INFO -     <<< rank: 0
# 04/24/2025 19:39:00 - INFO -     <<< resume_model: None
# 04/24/2025 19:39:00 - INFO -     <<< sampled_use_mil: False
# 04/24/2025 19:39:00 - INFO -     <<< seed: 42
# 04/24/2025 19:39:00 - INFO -     <<< sim_header: meanP
# 04/24/2025 19:39:00 - INFO -     <<< slice_framepos: 9
# 04/24/2025 19:39:00 - INFO -     <<< task_type: retrieval
# 04/24/2025 19:39:00 - INFO -     <<< text_num_hidden_layers: 12
# 04/24/2025 19:39:00 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/24/2025 19:39:00 - INFO -     <<< train_frame_order: 0
# 04/24/2025 19:39:00 - INFO -     <<< use_mil: False
# 04/24/2025 19:39:00 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/24/2025 19:39:00 - INFO -     <<< video_dim: 1024
# 04/24/2025 19:39:00 - INFO -     <<< visual_num_hidden_layers: 12
# 04/24/2025 19:39:00 - INFO -     <<< warmup_proportion: 0.1
# 04/24/2025 19:39:00 - INFO -     <<< world_size: 1
# 04/24/2025 19:39:00 - INFO -   device: cuda n_gpu: 1
# 04/24/2025 19:39:01 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/24/2025 19:39:01 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/24/2025 19:39:01 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/24/2025 19:39:01 - WARNING -   Stage-One:True, Stage-Two:False
# 04/24/2025 19:39:01 - WARNING -   Test retrieval by loose type.
# 04/24/2025 19:39:01 - WARNING -   	 embed_dim: 512
# 04/24/2025 19:39:01 - WARNING -   	 image_resolution: 224
# 04/24/2025 19:39:01 - WARNING -   	 vision_layers: 12
# 04/24/2025 19:39:01 - WARNING -   	 vision_width: 768
# 04/24/2025 19:39:01 - WARNING -   	 vision_patch_size: 32
# 04/24/2025 19:39:01 - WARNING -   	 context_length: 77
# 04/24/2025 19:39:01 - WARNING -   	 vocab_size: 49408
# 04/24/2025 19:39:01 - WARNING -   	 transformer_width: 512
# 04/24/2025 19:39:01 - WARNING -   	 transformer_heads: 8
# 04/24/2025 19:39:01 - WARNING -   	 transformer_layers: 12
# 04/24/2025 19:39:01 - WARNING -   		 linear_patch: 2d
# 04/24/2025 19:39:01 - WARNING -   	 cut_top_layer: 0
# 04/24/2025 19:39:02 - WARNING -   	 sim_header: meanP
# 04/24/2025 19:39:07 - INFO -   --------------------
# 04/24/2025 19:39:07 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/24/2025 19:39:08 - INFO -   ***** Running test *****
# 04/24/2025 19:39:08 - INFO -     Num examples = 1000
# 04/24/2025 19:39:08 - INFO -     Batch size = 8
# 04/24/2025 19:39:08 - INFO -     Num steps = 125
# 04/24/2025 19:39:08 - INFO -   ***** Running val *****
# 04/24/2025 19:39:08 - INFO -     Num examples = 1000
# 04/24/2025 19:39:12 - INFO -   ***** Running training *****
# 04/24/2025 19:39:12 - INFO -     Num examples = 18000
# 04/24/2025 19:39:12 - INFO -     Batch size = 64
# 04/24/2025 19:39:12 - INFO -     Num steps = 1405
# Epoch 1:  35% 99/281 [09:14<17:16,  5.70s/it, loss=0.821]04/24/2025 19:48:27 - INFO -   Epoch: 1/5, Step: 100/281, Lr: , Loss: 0.820837, Time/step: 5.544491
# Epoch 1:  71% 199/281 [16:13<02:22,  1.74s/it, loss=0.61] 04/24/2025 19:55:25 - INFO -   Epoch: 1/5, Step: 200/281, Lr: , Loss: 0.610322, Time/step: 4.188458
# Epoch 1: 100% 281/281 [21:43<00:00,  4.64s/it, loss=0.588]
# 04/24/2025 20:00:56 - INFO -   Epoch 1/5 Finished, Train Loss: 0.962392
# 04/24/2025 20:00:57 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/24/2025 20:00:57 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [03:03<00:00,  1.47s/it]
# 04/24/2025 20:04:06 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:04:06 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:04:06 - INFO -   Text-to-Video:
# 04/24/2025 20:04:06 - INFO -   	>>>  R@1: 37.0 - R@5: 63.6 - R@10: 74.8 - Median R: 3.0 - Mean R: 20.2
# 04/24/2025 20:04:06 - INFO -   Video-to-Text:
# 04/24/2025 20:04:06 - INFO -   	>>>  V2T$R@1: 37.3 - V2T$R@5: 64.9 - V2T$R@10: 75.9 - V2T$Median R: 3.0 - V2T$Mean R: 16.7
# 04/24/2025 20:04:06 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.0000
# Epoch 2:   6% 18/281 [01:42<29:02,  6.62s/it, loss=0.594]04/24/2025 20:05:49 - INFO -   Epoch: 2/5, Step: 19/281, Lr: , Loss: 0.594414, Time/step: 1.030121
# Epoch 2:  42% 118/281 [08:44<06:23,  2.36s/it, loss=0.69] 04/24/2025 20:12:52 - INFO -   Epoch: 2/5, Step: 119/281, Lr: , Loss: 0.689856, Time/step: 4.220458
# Epoch 2:  78% 218/281 [16:06<05:47,  5.52s/it, loss=0.481]04/24/2025 20:20:13 - INFO -   Epoch: 2/5, Step: 219/281, Lr: , Loss: 0.480754, Time/step: 4.418675
# Epoch 2: 100% 281/281 [20:09<00:00,  4.30s/it, loss=0.512]
# 04/24/2025 20:24:16 - INFO -   Epoch 2/5 Finished, Train Loss: 0.532752
# 04/24/2025 20:24:17 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/24/2025 20:24:17 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [01:12<00:00,  1.72it/s]
# 04/24/2025 20:25:36 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:25:36 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:25:36 - INFO -   Text-to-Video:
# 04/24/2025 20:25:36 - INFO -   	>>>  R@1: 36.1 - R@5: 63.8 - R@10: 75.4 - Median R: 3.0 - Mean R: 21.6
# 04/24/2025 20:25:36 - INFO -   Video-to-Text:
# 04/24/2025 20:25:36 - INFO -   	>>>  V2T$R@1: 36.6 - V2T$R@5: 65.5 - V2T$R@10: 75.6 - V2T$Median R: 3.0 - V2T$Mean R: 17.3
# 04/24/2025 20:25:36 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.0000
# Epoch 3:  13% 37/281 [03:00<13:30,  3.32s/it, loss=0.232]04/24/2025 20:28:37 - INFO -   Epoch: 3/5, Step: 38/281, Lr: , Loss: 0.231453, Time/step: 1.809311
# Epoch 3:  49% 137/281 [10:20<10:17,  4.29s/it, loss=0.38] 04/24/2025 20:35:57 - INFO -   Epoch: 3/5, Step: 138/281, Lr: , Loss: 0.379844, Time/step: 4.398840
# Epoch 3:  84% 237/281 [17:23<03:37,  4.95s/it, loss=0.279]04/24/2025 20:43:00 - INFO -   Epoch: 3/5, Step: 238/281, Lr: , Loss: 0.278657, Time/step: 4.231985
# Epoch 3: 100% 281/281 [20:06<00:00,  4.29s/it, loss=0.324]
# 04/24/2025 20:45:43 - INFO -   Epoch 3/5 Finished, Train Loss: 0.366777
# 04/24/2025 20:45:43 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/24/2025 20:45:43 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [01:10<00:00,  1.76it/s]
# 04/24/2025 20:47:01 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:47:01 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:47:01 - INFO -   Text-to-Video:
# 04/24/2025 20:47:01 - INFO -   	>>>  R@1: 35.6 - R@5: 62.6 - R@10: 74.8 - Median R: 3.0 - Mean R: 22.1
# 04/24/2025 20:47:01 - INFO -   Video-to-Text:
# 04/24/2025 20:47:01 - INFO -   	>>>  V2T$R@1: 35.0 - V2T$R@5: 63.3 - V2T$R@10: 74.8 - V2T$Median R: 3.0 - V2T$Mean R: 17.4
# 04/24/2025 20:47:01 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.0000
# Epoch 4:  20% 56/281 [04:42<07:20,  1.96s/it, loss=0.202]04/24/2025 20:51:43 - INFO -   Epoch: 4/5, Step: 57/281, Lr: , Loss: 0.201928, Time/step: 2.829044
# Epoch 4:  56% 156/281 [11:38<07:08,  3.42s/it, loss=0.243]04/24/2025 20:58:39 - INFO -   Epoch: 4/5, Step: 157/281, Lr: , Loss: 0.242609, Time/step: 4.159376
# Epoch 4:  91% 256/281 [19:01<00:44,  1.79s/it, loss=0.253]04/24/2025 21:06:02 - INFO -   Epoch: 4/5, Step: 257/281, Lr: , Loss: 0.253406, Time/step: 4.429741
# Epoch 4: 100% 281/281 [20:13<00:00,  4.32s/it, loss=0.384]
# 04/24/2025 21:07:15 - INFO -   Epoch 4/5 Finished, Train Loss: 0.303116
# 04/24/2025 21:07:15 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/24/2025 21:07:15 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [01:11<00:00,  1.74it/s]
# 04/24/2025 21:08:34 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 21:08:34 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 21:08:34 - INFO -   Text-to-Video:
# 04/24/2025 21:08:34 - INFO -   	>>>  R@1: 37.6 - R@5: 61.5 - R@10: 74.6 - Median R: 3.0 - Mean R: 23.0
# 04/24/2025 21:08:34 - INFO -   Video-to-Text:
# 04/24/2025 21:08:34 - INFO -   	>>>  V2T$R@1: 34.8 - V2T$R@5: 62.7 - V2T$R@10: 73.1 - V2T$Median R: 3.0 - V2T$Mean R: 18.4
# 04/24/2025 21:08:34 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 37.6000
# Epoch 5:  27% 75/281 [05:55<22:40,  6.60s/it, loss=0.254]04/24/2025 21:14:29 - INFO -   Epoch: 5/5, Step: 76/281, Lr: , Loss: 0.253949, Time/step: 3.556030
# Epoch 5:  62% 175/281 [12:57<04:30,  2.55s/it, loss=0.266]04/24/2025 21:21:32 - INFO -   Epoch: 5/5, Step: 176/281, Lr: , Loss: 0.265554, Time/step: 4.223752
# Epoch 5:  98% 275/281 [20:06<00:33,  5.66s/it, loss=0.233]04/24/2025 21:28:41 - INFO -   Epoch: 5/5, Step: 276/281, Lr: , Loss: 0.232756, Time/step: 4.290249
# Epoch 5: 100% 281/281 [20:09<00:00,  4.31s/it, loss=0.202]
# 04/24/2025 21:28:44 - INFO -   Epoch 5/5 Finished, Train Loss: 0.278068
# 04/24/2025 21:28:45 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/24/2025 21:28:45 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [01:11<00:00,  1.76it/s]
# 04/24/2025 21:30:02 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 21:30:02 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 21:30:02 - INFO -   Text-to-Video:
# 04/24/2025 21:30:02 - INFO -   	>>>  R@1: 36.2 - R@5: 62.6 - R@10: 75.0 - Median R: 3.0 - Mean R: 22.2
# 04/24/2025 21:30:02 - INFO -   Video-to-Text:
# 04/24/2025 21:30:02 - INFO -   	>>>  V2T$R@1: 35.2 - V2T$R@5: 62.9 - V2T$R@10: 74.7 - V2T$Median R: 3.0 - V2T$Mean R: 18.3
# 04/24/2025 21:30:02 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 37.6000
