# %%
# !git clone https://github.com/Hang-Ruan/CLIP_video.git
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 230 (delta 29), reused 0 (delta 0), pack-reused 187 (from 1)
# Receiving objects: 100% (230/230), 1.51 MiB | 4.07 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.5 (from boto3)
#   Downloading botocore-1.38.5-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.5-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 4.3 MB/s eta 0:00:00
# Downloading botocore-1.38.5-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 114.1 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.5 botocore-1.38.5 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/video"    # Directory of MSRVTT raw video

# %%
# import pandas as pd

# # Load training dataset
# train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
# df = pd.read_csv(train_path)

# print("Size: ", len(df))
# print("Column names", df.columns.tolist())
# display(df.head())

# # Choose a subset
# def sample_subset(df, frac=0.1, random_state=42):
#     return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# # Set fraction to 0.01
# subset_df = sample_subset(df, frac=0.1)
# print("Size of subset：", len(subset_df))
# display(subset_df.head())

# # Save the subset
# subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
# subset_df.to_csv(subset_path, index=False)

# print("Subset CSV saved to:", subset_path)

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA L4

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-30 00:41:58--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.70, 2620:1ec:bdf::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt’
#
# ViT-B-32.pt         100%[===================>] 337.58M  8.95MB/s    in 20s
#
# 2025-04-30 00:42:17 (17.3 MB/s) - ‘./modules/ViT-B-32.pt’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# Already up to date.

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=9498c042b24cf5969fdb159dc7167087b97508c177a9014a9f73de86d77d9814
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
# %%bash
# export DATA_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"
# export VIDEO_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/video"
#
# python /content/CLIP_video/main_task_retrieval.py \
#   --do_train \
#   --num_thread_reader 8 \
#   --epochs 20 \
#   --batch_size 64 \
#   --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
#   --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
#   --data_path  "$DATA_PATH"/MSRVTT_data.json \
#   --features_path "$VIDEO_PATH" \
#   --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
#   --lr 1e-4 \
#   --max_words 32 \
#   --max_frames 8 \
#   --batch_size_val 8 \
#   --datatype msrvtt \
#   --expand_msrvtt_sentences \
#   --feature_framerate 1 \
#   --coef_lr 1e-3 \
#   --freeze_layer_num 6 \
#   --slice_framepos 8 \
#   --loose_type \
#   --linear_patch 2d \
#   --sim_header meanP \
#   --pretrained_clip_name ViT-B/32 \
#   --fp16 \
#   --fp16_opt_level O1
# Out:
# 124/125
# 04/30/2025 00:42:26 - INFO -   Effective parameters:
# 04/30/2025 00:42:26 - INFO -     <<< batch_size: 64
# 04/30/2025 00:42:26 - INFO -     <<< batch_size_val: 8
# 04/30/2025 00:42:26 - INFO -     <<< cache_dir:
# 04/30/2025 00:42:26 - INFO -     <<< coef_lr: 0.001
# 04/30/2025 00:42:26 - INFO -     <<< cross_model: cross-base
# 04/30/2025 00:42:26 - INFO -     <<< cross_num_hidden_layers: 4
# 04/30/2025 00:42:26 - INFO -     <<< data_path: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_data.json
# 04/30/2025 00:42:26 - INFO -     <<< datatype: msrvtt
# 04/30/2025 00:42:26 - INFO -     <<< do_eval: False
# 04/30/2025 00:42:26 - INFO -     <<< do_lower_case: False
# 04/30/2025 00:42:26 - INFO -     <<< do_pretrain: False
# 04/30/2025 00:42:26 - INFO -     <<< do_train: True
# 04/30/2025 00:42:26 - INFO -     <<< epochs: 20
# 04/30/2025 00:42:26 - INFO -     <<< eval_frame_order: 0
# 04/30/2025 00:42:26 - INFO -     <<< expand_msrvtt_sentences: True
# 04/30/2025 00:42:26 - INFO -     <<< feature_framerate: 1
# 04/30/2025 00:42:26 - INFO -     <<< features_path: /content/drive/MyDrive/IDL/IDL Project/Data/video
# 04/30/2025 00:42:26 - INFO -     <<< fp16: True
# 04/30/2025 00:42:26 - INFO -     <<< fp16_opt_level: O1
# 04/30/2025 00:42:26 - INFO -     <<< freeze_layer_num: 6
# 04/30/2025 00:42:26 - INFO -     <<< gradient_accumulation_steps: 1
# 04/30/2025 00:42:26 - INFO -     <<< hard_negative_rate: 0.5
# 04/30/2025 00:42:26 - INFO -     <<< init_model: None
# 04/30/2025 00:42:26 - INFO -     <<< linear_patch: 2d
# 04/30/2025 00:42:26 - INFO -     <<< loose_type: True
# 04/30/2025 00:42:26 - INFO -     <<< lr: 0.0001
# 04/30/2025 00:42:26 - INFO -     <<< lr_decay: 0.9
# 04/30/2025 00:42:26 - INFO -     <<< margin: 0.1
# 04/30/2025 00:42:26 - INFO -     <<< max_frames: 8
# 04/30/2025 00:42:26 - INFO -     <<< max_words: 32
# 04/30/2025 00:42:26 - INFO -     <<< n_display: 100
# 04/30/2025 00:42:26 - INFO -     <<< n_gpu: 1
# 04/30/2025 00:42:26 - INFO -     <<< n_pair: 1
# 04/30/2025 00:42:26 - INFO -     <<< negative_weighting: 1
# 04/30/2025 00:42:26 - INFO -     <<< num_thread_reader: 8
# 04/30/2025 00:42:26 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/30/2025 00:42:26 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/30/2025 00:42:26 - INFO -     <<< rank: 0
# 04/30/2025 00:42:26 - INFO -     <<< resume_model: None
# 04/30/2025 00:42:26 - INFO -     <<< sampled_use_mil: False
# 04/30/2025 00:42:26 - INFO -     <<< seed: 42
# 04/30/2025 00:42:26 - INFO -     <<< sim_header: meanP
# 04/30/2025 00:42:26 - INFO -     <<< slice_framepos: 8
# 04/30/2025 00:42:26 - INFO -     <<< task_type: retrieval
# 04/30/2025 00:42:26 - INFO -     <<< text_num_hidden_layers: 12
# 04/30/2025 00:42:26 - INFO -     <<< train_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/30/2025 00:42:26 - INFO -     <<< train_frame_order: 0
# 04/30/2025 00:42:26 - INFO -     <<< use_mil: False
# 04/30/2025 00:42:26 - INFO -     <<< val_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/30/2025 00:42:26 - INFO -     <<< video_dim: 1024
# 04/30/2025 00:42:26 - INFO -     <<< visual_num_hidden_layers: 12
# 04/30/2025 00:42:26 - INFO -     <<< warmup_proportion: 0.1
# 04/30/2025 00:42:26 - INFO -     <<< world_size: 1
# 04/30/2025 00:42:26 - INFO -   device: cuda n_gpu: 1
# 100%|████████████████████████████████████████| 354M/354M [00:02<00:00, 153MiB/s]
# 04/30/2025 00:42:30 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/30/2025 00:42:30 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/30/2025 00:42:30 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/30/2025 00:42:30 - WARNING -   Stage-One:True, Stage-Two:False
# 04/30/2025 00:42:30 - WARNING -   Test retrieval by loose type.
# 04/30/2025 00:42:30 - WARNING -   	 embed_dim: 512
# 04/30/2025 00:42:30 - WARNING -   	 image_resolution: 224
# 04/30/2025 00:42:30 - WARNING -   	 vision_layers: 12
# 04/30/2025 00:42:30 - WARNING -   	 vision_width: 768
# 04/30/2025 00:42:30 - WARNING -   	 vision_patch_size: 32
# 04/30/2025 00:42:30 - WARNING -   	 context_length: 77
# 04/30/2025 00:42:30 - WARNING -   	 vocab_size: 49408
# 04/30/2025 00:42:30 - WARNING -   	 transformer_width: 512
# 04/30/2025 00:42:30 - WARNING -   	 transformer_heads: 8
# 04/30/2025 00:42:30 - WARNING -   	 transformer_layers: 12
# 04/30/2025 00:42:30 - WARNING -   		 linear_patch: 2d
# 04/30/2025 00:42:30 - WARNING -   	 cut_top_layer: 0
# 04/30/2025 00:42:32 - WARNING -   	 sim_header: meanP
# 04/30/2025 00:42:36 - INFO -   --------------------
# 04/30/2025 00:42:36 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/30/2025 00:42:39 - INFO -   ***** Running test *****
# 04/30/2025 00:42:39 - INFO -     Num examples = 1000
# 04/30/2025 00:42:39 - INFO -     Batch size = 8
# 04/30/2025 00:42:39 - INFO -     Num steps = 125
# 04/30/2025 00:42:39 - INFO -   ***** Running val *****
# 04/30/2025 00:42:39 - INFO -     Num examples = 1000
# 04/30/2025 00:42:44 - INFO -   ***** Running training *****
# 04/30/2025 00:42:44 - INFO -     Num examples = 18000
# 04/30/2025 00:42:44 - INFO -     Batch size = 64
# 04/30/2025 00:42:44 - INFO -     Num steps = 5620
# Epoch 1:  35%|███▌      | 99/281 [08:30<18:44,  6.18s/it, loss=1.18]04/30/2025 00:51:15 - INFO -   Epoch: 1/20, Step: 100/281, Lr: , Loss: 1.176206, Time/step: 5.110044
# Epoch 1:  71%|███████   | 199/281 [15:36<03:03,  2.23s/it, loss=0.843]04/30/2025 00:58:21 - INFO -   Epoch: 1/20, Step: 200/281, Lr: , Loss: 0.842781, Time/step: 4.260994
# Epoch 1: 100%|██████████| 281/281 [21:01<00:00,  4.49s/it, loss=0.717]
# 04/30/2025 01:03:46 - INFO -   Epoch 1/20 Finished, Train Loss: 1.181514
# 04/30/2025 01:03:47 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/30/2025 01:03:47 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100%|██████████| 125/125 [01:49<00:00,  1.14it/s]
# 04/30/2025 01:05:42 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 01:05:42 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 01:05:42 - INFO -   Text-to-Video:
# 04/30/2025 01:05:42 - INFO -   	>>>  R@1: 37.1 - R@5: 62.0 - R@10: 73.3 - Median R: 3.0 - Mean R: 21.1
# 04/30/2025 01:05:42 - INFO -   Video-to-Text:
# 04/30/2025 01:05:42 - INFO -   	>>>  V2T$R@1: 38.8 - V2T$R@5: 63.8 - V2T$R@10: 73.9 - V2T$Median R: 3.0 - V2T$Mean R: 18.4
# 04/30/2025 01:05:42 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.1000
# Epoch 2:   6%|▋         | 18/281 [01:43<28:47,  6.57s/it, loss=0.908]04/30/2025 01:07:26 - INFO -   Epoch: 2/20, Step: 19/281, Lr: , Loss: 0.907901, Time/step: 1.034549
# Epoch 2:  42%|████▏     | 118/281 [08:51<07:46,  2.86s/it, loss=0.812]04/30/2025 01:14:35 - INFO -   Epoch: 2/20, Step: 119/281, Lr: , Loss: 0.812289, Time/step: 4.286442
# Epoch 2:  78%|███████▊  | 218/281 [16:10<05:27,  5.19s/it, loss=0.502]04/30/2025 01:21:53 - INFO -   Epoch: 2/20, Step: 219/281, Lr: , Loss: 0.502203, Time/step: 4.388424
# Epoch 2: 100%|██████████| 281/281 [20:14<00:00,  4.32s/it, loss=0.681]
# 04/30/2025 01:25:57 - INFO -   Epoch 2/20 Finished, Train Loss: 0.717132
# 04/30/2025 01:25:58 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/30/2025 01:25:58 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.76it/s]
# 04/30/2025 01:27:15 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 01:27:15 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 01:27:15 - INFO -   Text-to-Video:
# 04/30/2025 01:27:15 - INFO -   	>>>  R@1: 37.2 - R@5: 62.3 - R@10: 74.4 - Median R: 3.0 - Mean R: 20.1
# 04/30/2025 01:27:15 - INFO -   Video-to-Text:
# 04/30/2025 01:27:15 - INFO -   	>>>  V2T$R@1: 36.3 - V2T$R@5: 65.1 - V2T$R@10: 75.6 - V2T$Median R: 3.0 - V2T$Mean R: 16.9
# 04/30/2025 01:27:15 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 37.2000
# Epoch 3:  13%|█▎        | 37/281 [03:03<14:37,  3.59s/it, loss=0.36] 04/30/2025 01:30:19 - INFO -   Epoch: 3/20, Step: 38/281, Lr: , Loss: 0.359776, Time/step: 1.837990
# Epoch 3:  49%|████▉     | 137/281 [10:28<06:53,  2.87s/it, loss=0.426]04/30/2025 01:37:44 - INFO -   Epoch: 3/20, Step: 138/281, Lr: , Loss: 0.425800, Time/step: 4.445560
# Epoch 3:  84%|████████▍ | 237/281 [17:29<03:16,  4.46s/it, loss=0.345]04/30/2025 01:44:44 - INFO -   Epoch: 3/20, Step: 238/281, Lr: , Loss: 0.345244, Time/step: 4.209622
# Epoch 3: 100%|██████████| 281/281 [20:17<00:00,  4.33s/it, loss=0.458]
# 04/30/2025 01:47:33 - INFO -   Epoch 3/20 Finished, Train Loss: 0.487989
# 04/30/2025 01:47:34 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/30/2025 01:47:34 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 01:48:51 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 01:48:51 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 01:48:51 - INFO -   Text-to-Video:
# 04/30/2025 01:48:51 - INFO -   	>>>  R@1: 37.3 - R@5: 64.1 - R@10: 75.0 - Median R: 3.0 - Mean R: 20.2
# 04/30/2025 01:48:51 - INFO -   Video-to-Text:
# 04/30/2025 01:48:51 - INFO -   	>>>  V2T$R@1: 36.4 - V2T$R@5: 64.6 - V2T$R@10: 75.5 - V2T$Median R: 3.0 - V2T$Mean R: 16.0
# 04/30/2025 01:48:51 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 37.3000
# Epoch 4:  20%|█▉        | 56/281 [04:47<07:09,  1.91s/it, loss=0.264]04/30/2025 01:53:38 - INFO -   Epoch: 4/20, Step: 57/281, Lr: , Loss: 0.263988, Time/step: 2.872293
# Epoch 4:  56%|█████▌    | 156/281 [11:48<07:52,  3.78s/it, loss=0.353]04/30/2025 02:00:40 - INFO -   Epoch: 4/20, Step: 157/281, Lr: , Loss: 0.353058, Time/step: 4.217093
# Epoch 4:  91%|█████████ | 256/281 [19:08<00:43,  1.74s/it, loss=0.262]04/30/2025 02:08:00 - INFO -   Epoch: 4/20, Step: 257/281, Lr: , Loss: 0.262140, Time/step: 4.398638
# Epoch 4: 100%|██████████| 281/281 [20:17<00:00,  4.33s/it, loss=0.402]
# 04/30/2025 02:09:09 - INFO -   Epoch 4/20 Finished, Train Loss: 0.355228
# 04/30/2025 02:09:10 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/30/2025 02:09:10 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.76it/s]
# 04/30/2025 02:10:27 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 02:10:27 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 02:10:27 - INFO -   Text-to-Video:
# 04/30/2025 02:10:27 - INFO -   	>>>  R@1: 36.6 - R@5: 62.0 - R@10: 73.0 - Median R: 3.0 - Mean R: 21.3
# 04/30/2025 02:10:27 - INFO -   Video-to-Text:
# 04/30/2025 02:10:27 - INFO -   	>>>  V2T$R@1: 35.3 - V2T$R@5: 62.3 - V2T$R@10: 72.4 - V2T$Median R: 3.0 - V2T$Mean R: 17.7
# 04/30/2025 02:10:27 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 37.3000
# Epoch 5:  27%|██▋       | 75/281 [05:54<20:59,  6.12s/it, loss=0.256]04/30/2025 02:16:21 - INFO -   Epoch: 5/20, Step: 76/281, Lr: , Loss: 0.255732, Time/step: 3.544397
# Epoch 5:  62%|██████▏   | 175/281 [13:03<05:10,  2.93s/it, loss=0.259]04/30/2025 02:23:31 - INFO -   Epoch: 5/20, Step: 176/281, Lr: , Loss: 0.259337, Time/step: 4.294567
# Epoch 5:  98%|█████████▊| 275/281 [20:14<00:30,  5.13s/it, loss=0.218]04/30/2025 02:30:42 - INFO -   Epoch: 5/20, Step: 276/281, Lr: , Loss: 0.218462, Time/step: 4.311130
# Epoch 5: 100%|██████████| 281/281 [20:19<00:00,  4.34s/it, loss=0.236]
# 04/30/2025 02:30:47 - INFO -   Epoch 5/20 Finished, Train Loss: 0.269314
# 04/30/2025 02:30:47 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/30/2025 02:30:47 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.74it/s]
# 04/30/2025 02:32:06 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 02:32:06 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 02:32:06 - INFO -   Text-to-Video:
# 04/30/2025 02:32:06 - INFO -   	>>>  R@1: 36.9 - R@5: 63.2 - R@10: 75.0 - Median R: 3.0 - Mean R: 21.8
# 04/30/2025 02:32:06 - INFO -   Video-to-Text:
# 04/30/2025 02:32:06 - INFO -   	>>>  V2T$R@1: 36.0 - V2T$R@5: 61.1 - V2T$R@10: 73.4 - V2T$Median R: 3.0 - V2T$Mean R: 18.7
# 04/30/2025 02:32:06 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 37.3000
# Epoch 6:  33%|███▎      | 94/281 [07:09<07:41,  2.47s/it, loss=0.181]04/30/2025 02:39:15 - INFO -   Epoch: 6/20, Step: 95/281, Lr: , Loss: 0.181354, Time/step: 4.294784
# Epoch 6:  69%|██████▉   | 194/281 [14:39<10:15,  7.08s/it, loss=0.237]04/30/2025 02:46:46 - INFO -   Epoch: 6/20, Step: 195/281, Lr: , Loss: 0.237392, Time/step: 4.501406
# Epoch 6: 100%|██████████| 281/281 [20:16<00:00,  4.33s/it, loss=0.132]
# 04/30/2025 02:52:23 - INFO -   Epoch 6/20 Finished, Train Loss: 0.218341
# 04/30/2025 02:52:23 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.5
# 04/30/2025 02:52:23 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.5
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 02:53:40 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 02:53:40 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 02:53:40 - INFO -   Text-to-Video:
# 04/30/2025 02:53:40 - INFO -   	>>>  R@1: 37.2 - R@5: 62.3 - R@10: 74.2 - Median R: 3.0 - Mean R: 22.6
# 04/30/2025 02:53:40 - INFO -   Video-to-Text:
# 04/30/2025 02:53:40 - INFO -   	>>>  V2T$R@1: 34.9 - V2T$R@5: 61.8 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.2
# 04/30/2025 02:53:41 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 37.3000
# Epoch 7:   5%|▍         | 13/281 [01:17<16:52,  3.78s/it, loss=0.0779]04/30/2025 02:54:59 - INFO -   Epoch: 7/20, Step: 14/281, Lr: , Loss: 0.077889, Time/step: 0.780727
# Epoch 7:  40%|████      | 113/281 [08:37<22:54,  8.18s/it, loss=0.141]04/30/2025 03:02:19 - INFO -   Epoch: 7/20, Step: 114/281, Lr: , Loss: 0.140472, Time/step: 4.398792
# Epoch 7:  76%|███████▌  | 213/281 [15:44<03:20,  2.95s/it, loss=0.226]04/30/2025 03:09:25 - INFO -   Epoch: 7/20, Step: 214/281, Lr: , Loss: 0.225493, Time/step: 4.262173
# Epoch 7: 100%|██████████| 281/281 [20:17<00:00,  4.33s/it, loss=0.158]
# 04/30/2025 03:13:58 - INFO -   Epoch 7/20 Finished, Train Loss: 0.189599
# 04/30/2025 03:13:59 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.6
# 04/30/2025 03:13:59 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.6
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 03:15:16 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 03:15:16 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 03:15:16 - INFO -   Text-to-Video:
# 04/30/2025 03:15:16 - INFO -   	>>>  R@1: 37.5 - R@5: 63.4 - R@10: 73.8 - Median R: 3.0 - Mean R: 22.5
# 04/30/2025 03:15:16 - INFO -   Video-to-Text:
# 04/30/2025 03:15:16 - INFO -   	>>>  V2T$R@1: 34.9 - V2T$R@5: 61.9 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.0
# 04/30/2025 03:15:16 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.6, the R1 is: 37.5000
# Epoch 8:  11%|█▏        | 32/281 [02:53<07:28,  1.80s/it, loss=0.137]04/30/2025 03:18:10 - INFO -   Epoch: 8/20, Step: 33/281, Lr: , Loss: 0.137218, Time/step: 1.737156
# Epoch 8:  47%|████▋     | 132/281 [10:12<19:37,  7.90s/it, loss=0.11] 04/30/2025 03:25:29 - INFO -   Epoch: 8/20, Step: 133/281, Lr: , Loss: 0.110391, Time/step: 4.392452
# Epoch 8:  83%|████████▎ | 232/281 [17:30<02:33,  3.14s/it, loss=0.109]04/30/2025 03:32:47 - INFO -   Epoch: 8/20, Step: 233/281, Lr: , Loss: 0.108881, Time/step: 4.376536
# Epoch 8: 100%|██████████| 281/281 [20:28<00:00,  4.37s/it, loss=0.155]
# 04/30/2025 03:35:45 - INFO -   Epoch 8/20 Finished, Train Loss: 0.164306
# 04/30/2025 03:35:46 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7
# 04/30/2025 03:35:46 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.7
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.73it/s]
# 04/30/2025 03:37:04 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 03:37:04 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 03:37:04 - INFO -   Text-to-Video:
# 04/30/2025 03:37:04 - INFO -   	>>>  R@1: 37.7 - R@5: 63.4 - R@10: 73.6 - Median R: 3.0 - Mean R: 22.3
# 04/30/2025 03:37:04 - INFO -   Video-to-Text:
# 04/30/2025 03:37:04 - INFO -   	>>>  V2T$R@1: 35.2 - V2T$R@5: 60.6 - V2T$R@10: 71.3 - V2T$Median R: 3.0 - V2T$Mean R: 19.1
# 04/30/2025 03:37:04 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7, the R1 is: 37.7000
# Epoch 9:  18%|█▊        | 51/281 [04:12<23:26,  6.11s/it, loss=0.123] 04/30/2025 03:41:17 - INFO -   Epoch: 9/20, Step: 52/281, Lr: , Loss: 0.123000, Time/step: 2.521963
# Epoch 9:  54%|█████▎    | 151/281 [11:15<08:47,  4.06s/it, loss=0.113]04/30/2025 03:48:20 - INFO -   Epoch: 9/20, Step: 152/281, Lr: , Loss: 0.113090, Time/step: 4.235534
# Epoch 9:  89%|████████▉ | 251/281 [18:32<02:41,  5.39s/it, loss=0.0486]04/30/2025 03:55:37 - INFO -   Epoch: 9/20, Step: 252/281, Lr: , Loss: 0.048564, Time/step: 4.370294
# Epoch 9: 100%|██████████| 281/281 [20:14<00:00,  4.32s/it, loss=0.224]
# 04/30/2025 03:57:19 - INFO -   Epoch 9/20 Finished, Train Loss: 0.152144
# 04/30/2025 03:57:20 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.8
# 04/30/2025 03:57:20 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.8
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 03:58:37 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 03:58:37 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 03:58:37 - INFO -   Text-to-Video:
# 04/30/2025 03:58:37 - INFO -   	>>>  R@1: 37.6 - R@5: 63.7 - R@10: 74.3 - Median R: 3.0 - Mean R: 22.4
# 04/30/2025 03:58:37 - INFO -   Video-to-Text:
# 04/30/2025 03:58:37 - INFO -   	>>>  V2T$R@1: 34.7 - V2T$R@5: 61.6 - V2T$R@10: 72.8 - V2T$Median R: 3.0 - V2T$Mean R: 18.5
# 04/30/2025 03:58:37 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7, the R1 is: 37.7000
# Epoch 10:  25%|██▍       | 70/281 [05:21<09:21,  2.66s/it, loss=0.13] 04/30/2025 04:03:59 - INFO -   Epoch: 10/20, Step: 71/281, Lr: , Loss: 0.130164, Time/step: 3.220296
# Epoch 10:  60%|██████    | 170/281 [12:48<08:59,  4.86s/it, loss=0.119] 04/30/2025 04:11:25 - INFO -   Epoch: 10/20, Step: 171/281, Lr: , Loss: 0.119247, Time/step: 4.464270
# Epoch 10:  96%|█████████▌| 270/281 [19:50<00:26,  2.45s/it, loss=0.255] 04/30/2025 04:18:28 - INFO -   Epoch: 10/20, Step: 271/281, Lr: , Loss: 0.254605, Time/step: 4.226065
# Epoch 10: 100%|██████████| 281/281 [20:18<00:00,  4.33s/it, loss=0.215]
# 04/30/2025 04:18:55 - INFO -   Epoch 10/20 Finished, Train Loss: 0.137583
# 04/30/2025 04:18:56 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.9
# 04/30/2025 04:18:56 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.9
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.74it/s]
# 04/30/2025 04:20:15 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 04:20:15 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 04:20:15 - INFO -   Text-to-Video:
# 04/30/2025 04:20:15 - INFO -   	>>>  R@1: 37.5 - R@5: 63.0 - R@10: 73.8 - Median R: 3.0 - Mean R: 22.2
# 04/30/2025 04:20:15 - INFO -   Video-to-Text:
# 04/30/2025 04:20:15 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 60.2 - V2T$R@10: 72.3 - V2T$Median R: 3.0 - V2T$Mean R: 18.5
# 04/30/2025 04:20:15 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7, the R1 is: 37.7000
# Epoch 11:  32%|███▏      | 89/281 [06:56<24:39,  7.70s/it, loss=0.16]  04/30/2025 04:27:11 - INFO -   Epoch: 11/20, Step: 90/281, Lr: , Loss: 0.160315, Time/step: 4.167509
# Epoch 11:  67%|██████▋   | 189/281 [14:01<07:08,  4.66s/it, loss=0.188] 04/30/2025 04:34:16 - INFO -   Epoch: 11/20, Step: 190/281, Lr: , Loss: 0.188180, Time/step: 4.249096
# Epoch 11: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.146]
# 04/30/2025 04:40:29 - INFO -   Epoch 11/20 Finished, Train Loss: 0.126244
# 04/30/2025 04:40:29 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.10
# 04/30/2025 04:40:29 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.10
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.73it/s]
# 04/30/2025 04:41:48 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 04:41:48 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 04:41:48 - INFO -   Text-to-Video:
# 04/30/2025 04:41:48 - INFO -   	>>>  R@1: 37.3 - R@5: 62.5 - R@10: 74.5 - Median R: 3.0 - Mean R: 22.3
# 04/30/2025 04:41:48 - INFO -   Video-to-Text:
# 04/30/2025 04:41:48 - INFO -   	>>>  V2T$R@1: 33.6 - V2T$R@5: 61.1 - V2T$R@10: 71.9 - V2T$Median R: 3.0 - V2T$Mean R: 19.0
# 04/30/2025 04:41:48 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7, the R1 is: 37.7000
# Epoch 12:   3%|▎         | 8/281 [01:09<08:53,  1.95s/it, loss=0.173] 04/30/2025 04:42:58 - INFO -   Epoch: 12/20, Step: 9/281, Lr: , Loss: 0.172988, Time/step: 0.699012
# Epoch 12:  38%|███▊      | 108/281 [08:10<11:49,  4.10s/it, loss=0.0898]04/30/2025 04:49:59 - INFO -   Epoch: 12/20, Step: 109/281, Lr: , Loss: 0.089788, Time/step: 4.211978
# Epoch 12:  74%|███████▍  | 208/281 [15:33<02:44,  2.26s/it, loss=0.108]04/30/2025 04:57:22 - INFO -   Epoch: 12/20, Step: 209/281, Lr: , Loss: 0.108423, Time/step: 4.423757
# Epoch 12: 100%|██████████| 281/281 [20:20<00:00,  4.34s/it, loss=0.0803]
# 04/30/2025 05:02:09 - INFO -   Epoch 12/20 Finished, Train Loss: 0.122262
# 04/30/2025 05:02:10 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.11
# 04/30/2025 05:02:10 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.11
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 05:03:27 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 05:03:27 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 05:03:27 - INFO -   Text-to-Video:
# 04/30/2025 05:03:27 - INFO -   	>>>  R@1: 36.7 - R@5: 61.9 - R@10: 74.0 - Median R: 3.0 - Mean R: 22.5
# 04/30/2025 05:03:27 - INFO -   Video-to-Text:
# 04/30/2025 05:03:27 - INFO -   	>>>  V2T$R@1: 34.7 - V2T$R@5: 61.1 - V2T$R@10: 71.9 - V2T$Median R: 3.0 - V2T$Mean R: 19.2
# 04/30/2025 05:03:27 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7, the R1 is: 37.7000
# Epoch 13:  10%|▉         | 27/281 [02:27<25:32,  6.03s/it, loss=0.0987]04/30/2025 05:05:55 - INFO -   Epoch: 13/20, Step: 28/281, Lr: , Loss: 0.098749, Time/step: 1.480488
# Epoch 13:  45%|████▌     | 127/281 [09:26<06:21,  2.48s/it, loss=0.12] 04/30/2025 05:12:54 - INFO -   Epoch: 13/20, Step: 128/281, Lr: , Loss: 0.120485, Time/step: 4.184168
# Epoch 13:  81%|████████  | 227/281 [16:47<05:37,  6.26s/it, loss=0.12]  04/30/2025 05:20:14 - INFO -   Epoch: 13/20, Step: 228/281, Lr: , Loss: 0.119818, Time/step: 4.407447
# Epoch 13: 100%|██████████| 281/281 [20:14<00:00,  4.32s/it, loss=0.101]
# 04/30/2025 05:23:41 - INFO -   Epoch 13/20 Finished, Train Loss: 0.111660
# 04/30/2025 05:23:42 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12
# 04/30/2025 05:23:42 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.12
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/30/2025 05:25:00 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 05:25:00 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 05:25:00 - INFO -   Text-to-Video:
# 04/30/2025 05:25:00 - INFO -   	>>>  R@1: 37.7 - R@5: 61.7 - R@10: 73.4 - Median R: 3.0 - Mean R: 22.5
# 04/30/2025 05:25:00 - INFO -   Video-to-Text:
# 04/30/2025 05:25:00 - INFO -   	>>>  V2T$R@1: 33.9 - V2T$R@5: 61.1 - V2T$R@10: 72.1 - V2T$Median R: 3.0 - V2T$Mean R: 19.2
# 04/30/2025 05:25:00 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 14:  16%|█▋        | 46/281 [03:45<10:04,  2.57s/it, loss=0.0984]04/30/2025 05:28:46 - INFO -   Epoch: 14/20, Step: 47/281, Lr: , Loss: 0.098352, Time/step: 2.254104
# Epoch 14:  52%|█████▏    | 146/281 [11:14<14:41,  6.53s/it, loss=0.103] 04/30/2025 05:36:15 - INFO -   Epoch: 14/20, Step: 147/281, Lr: , Loss: 0.103249, Time/step: 4.491457
# Epoch 14:  88%|████████▊ | 246/281 [18:02<01:16,  2.18s/it, loss=0.0788]04/30/2025 05:43:03 - INFO -   Epoch: 14/20, Step: 247/281, Lr: , Loss: 0.078814, Time/step: 4.082053
# Epoch 14: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.0656]
# 04/30/2025 05:45:14 - INFO -   Epoch 14/20 Finished, Train Loss: 0.109913
# 04/30/2025 05:45:15 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.13
# 04/30/2025 05:45:15 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.13
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.76it/s]
# 04/30/2025 05:46:32 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 05:46:32 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 05:46:32 - INFO -   Text-to-Video:
# 04/30/2025 05:46:32 - INFO -   	>>>  R@1: 37.6 - R@5: 62.4 - R@10: 73.4 - Median R: 3.0 - Mean R: 22.8
# 04/30/2025 05:46:32 - INFO -   Video-to-Text:
# 04/30/2025 05:46:32 - INFO -   	>>>  V2T$R@1: 34.0 - V2T$R@5: 61.2 - V2T$R@10: 71.9 - V2T$Median R: 3.0 - V2T$Mean R: 19.3
# 04/30/2025 05:46:32 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 15:  23%|██▎       | 65/281 [05:10<33:36,  9.34s/it, loss=0.0543]04/30/2025 05:51:43 - INFO -   Epoch: 15/20, Step: 66/281, Lr: , Loss: 0.054275, Time/step: 3.109325
# Epoch 15:  59%|█████▊    | 165/281 [12:09<06:18,  3.26s/it, loss=0.141] 04/30/2025 05:58:42 - INFO -   Epoch: 15/20, Step: 166/281, Lr: , Loss: 0.140979, Time/step: 4.187518
# Epoch 15:  94%|█████████▍| 265/281 [19:32<02:24,  9.05s/it, loss=0.155]04/30/2025 06:06:05 - INFO -   Epoch: 15/20, Step: 266/281, Lr: , Loss: 0.154589, Time/step: 4.433104
# Epoch 15: 100%|██████████| 281/281 [20:11<00:00,  4.31s/it, loss=0.057]
# 04/30/2025 06:06:44 - INFO -   Epoch 15/20 Finished, Train Loss: 0.110573
# 04/30/2025 06:06:45 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.14
# 04/30/2025 06:06:45 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.14
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.78it/s]
# 04/30/2025 06:08:02 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 06:08:02 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 06:08:02 - INFO -   Text-to-Video:
# 04/30/2025 06:08:02 - INFO -   	>>>  R@1: 37.5 - R@5: 61.9 - R@10: 73.3 - Median R: 3.0 - Mean R: 23.0
# 04/30/2025 06:08:02 - INFO -   Video-to-Text:
# 04/30/2025 06:08:02 - INFO -   	>>>  V2T$R@1: 33.8 - V2T$R@5: 60.9 - V2T$R@10: 71.9 - V2T$Median R: 3.0 - V2T$Mean R: 19.3
# 04/30/2025 06:08:02 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 16:  30%|██▉       | 84/281 [06:20<11:57,  3.64s/it, loss=0.154] 04/30/2025 06:14:22 - INFO -   Epoch: 16/20, Step: 85/281, Lr: , Loss: 0.153658, Time/step: 3.802656
# Epoch 16:  65%|██████▌   | 184/281 [13:47<03:09,  1.95s/it, loss=0.138] 04/30/2025 06:21:50 - INFO -   Epoch: 16/20, Step: 185/281, Lr: , Loss: 0.137732, Time/step: 4.475411
# Epoch 16: 100%|██████████| 281/281 [20:11<00:00,  4.31s/it, loss=0.0114]
# 04/30/2025 06:28:13 - INFO -   Epoch 16/20 Finished, Train Loss: 0.101985
# 04/30/2025 06:28:14 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.15
# 04/30/2025 06:28:14 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.15
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/30/2025 06:29:32 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 06:29:32 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 06:29:32 - INFO -   Text-to-Video:
# 04/30/2025 06:29:32 - INFO -   	>>>  R@1: 37.4 - R@5: 62.3 - R@10: 73.4 - Median R: 3.0 - Mean R: 22.9
# 04/30/2025 06:29:32 - INFO -   Video-to-Text:
# 04/30/2025 06:29:32 - INFO -   	>>>  V2T$R@1: 34.1 - V2T$R@5: 60.7 - V2T$R@10: 71.8 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/30/2025 06:29:32 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 17:   1%|          | 3/281 [00:39<41:19,  8.92s/it, loss=0.129] 04/30/2025 06:30:11 - INFO -   Epoch: 17/20, Step: 4/281, Lr: , Loss: 0.128636, Time/step: 0.391880
# Epoch 17:  37%|███▋      | 103/281 [07:39<09:40,  3.26s/it, loss=0.149]04/30/2025 06:37:12 - INFO -   Epoch: 17/20, Step: 104/281, Lr: , Loss: 0.149475, Time/step: 4.207951
# Epoch 17:  72%|███████▏  | 203/281 [15:02<06:59,  5.38s/it, loss=0.111]04/30/2025 06:44:35 - INFO -   Epoch: 17/20, Step: 204/281, Lr: , Loss: 0.111051, Time/step: 4.430469
# Epoch 17: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.0877]
# 04/30/2025 06:49:46 - INFO -   Epoch 17/20 Finished, Train Loss: 0.101180
# 04/30/2025 06:49:47 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.16
# 04/30/2025 06:49:47 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.16
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/30/2025 06:51:05 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 06:51:05 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 06:51:05 - INFO -   Text-to-Video:
# 04/30/2025 06:51:05 - INFO -   	>>>  R@1: 37.4 - R@5: 62.1 - R@10: 73.4 - Median R: 3.0 - Mean R: 23.0
# 04/30/2025 06:51:05 - INFO -   Video-to-Text:
# 04/30/2025 06:51:05 - INFO -   	>>>  V2T$R@1: 34.0 - V2T$R@5: 60.7 - V2T$R@10: 72.2 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/30/2025 06:51:05 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 18:   8%|▊         | 22/281 [01:53<10:25,  2.42s/it, loss=0.143]04/30/2025 06:52:58 - INFO -   Epoch: 18/20, Step: 23/281, Lr: , Loss: 0.142810, Time/step: 1.131991
# Epoch 18:  43%|████▎     | 122/281 [09:18<16:23,  6.18s/it, loss=0.0582]04/30/2025 07:00:24 - INFO -   Epoch: 18/20, Step: 123/281, Lr: , Loss: 0.058179, Time/step: 4.452949
# Epoch 18:  79%|███████▉  | 222/281 [16:19<03:16,  3.33s/it, loss=0.0633]04/30/2025 07:07:25 - INFO -   Epoch: 18/20, Step: 223/281, Lr: , Loss: 0.063311, Time/step: 4.212448
# Epoch 18: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.031]
# 04/30/2025 07:11:19 - INFO -   Epoch 18/20 Finished, Train Loss: 0.100207
# 04/30/2025 07:11:20 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.17
# 04/30/2025 07:11:20 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.17
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/30/2025 07:12:38 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 07:12:38 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 07:12:38 - INFO -   Text-to-Video:
# 04/30/2025 07:12:38 - INFO -   	>>>  R@1: 37.3 - R@5: 62.0 - R@10: 73.6 - Median R: 3.0 - Mean R: 23.0
# 04/30/2025 07:12:38 - INFO -   Video-to-Text:
# 04/30/2025 07:12:38 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 60.6 - V2T$R@10: 72.1 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/30/2025 07:12:38 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 19:  15%|█▍        | 41/281 [03:40<44:36, 11.15s/it, loss=0.178]04/30/2025 07:16:18 - INFO -   Epoch: 19/20, Step: 42/281, Lr: , Loss: 0.178030, Time/step: 2.201772
# Epoch 19:  50%|█████     | 141/281 [10:28<06:31,  2.79s/it, loss=0.131]04/30/2025 07:23:07 - INFO -   Epoch: 19/20, Step: 142/281, Lr: , Loss: 0.130638, Time/step: 4.085193
# Epoch 19:  86%|████████▌ | 241/281 [17:51<06:20,  9.50s/it, loss=0.139]04/30/2025 07:30:30 - INFO -   Epoch: 19/20, Step: 242/281, Lr: , Loss: 0.139328, Time/step: 4.430438
# Epoch 19: 100%|██████████| 281/281 [20:10<00:00,  4.31s/it, loss=0.0521]
# 04/30/2025 07:32:49 - INFO -   Epoch 19/20 Finished, Train Loss: 0.107318
# 04/30/2025 07:32:50 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.18
# 04/30/2025 07:32:50 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.18
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/30/2025 07:34:07 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 07:34:07 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 07:34:07 - INFO -   Text-to-Video:
# 04/30/2025 07:34:07 - INFO -   	>>>  R@1: 37.3 - R@5: 62.0 - R@10: 73.6 - Median R: 3.0 - Mean R: 23.0
# 04/30/2025 07:34:07 - INFO -   Video-to-Text:
# 04/30/2025 07:34:07 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 60.7 - V2T$R@10: 72.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/30/2025 07:34:07 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
# Epoch 20:  21%|██▏       | 60/281 [04:39<13:06,  3.56s/it, loss=0.1]   04/30/2025 07:38:46 - INFO -   Epoch: 20/20, Step: 61/281, Lr: , Loss: 0.100243, Time/step: 2.792313
# Epoch 20:  57%|█████▋    | 160/281 [12:02<03:42,  1.84s/it, loss=0.132]04/30/2025 07:46:09 - INFO -   Epoch: 20/20, Step: 161/281, Lr: , Loss: 0.131659, Time/step: 4.431499
# Epoch 20:  93%|█████████▎| 260/281 [18:59<01:18,  3.72s/it, loss=0.112]04/30/2025 07:53:07 - INFO -   Epoch: 20/20, Step: 261/281, Lr: , Loss: 0.112359, Time/step: 4.174559
# Epoch 20: 100%|██████████| 281/281 [20:09<00:00,  4.30s/it, loss=0.0964]
# 04/30/2025 07:54:16 - INFO -   Epoch 20/20 Finished, Train Loss: 0.100900
# 04/30/2025 07:54:17 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.19
# 04/30/2025 07:54:17 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.19
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/30/2025 07:55:35 - INFO -   sim matrix size: 1000, 1000
# 04/30/2025 07:55:35 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/30/2025 07:55:35 - INFO -   Text-to-Video:
# 04/30/2025 07:55:35 - INFO -   	>>>  R@1: 37.3 - R@5: 62.0 - R@10: 73.6 - Median R: 3.0 - Mean R: 23.0
# 04/30/2025 07:55:35 - INFO -   Video-to-Text:
# 04/30/2025 07:55:35 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 60.7 - V2T$R@10: 72.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/30/2025 07:55:35 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12, the R1 is: 37.7000
