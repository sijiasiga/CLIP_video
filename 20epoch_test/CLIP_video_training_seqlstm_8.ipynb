# %%
# !git clone https://github.com/Hang-Ruan/CLIP_video.git
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 230, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 230 (delta 29), reused 0 (delta 0), pack-reused 187 (from 1)
# Receiving objects: 100% (230/230), 1.51 MiB | 4.05 MiB/s, done.
# Resolving deltas: 100% (128/128), done.

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.4 (from boto3)
#   Downloading botocore-1.38.4-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.4-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 5.9 MB/s eta 0:00:00
# Downloading botocore-1.38.4-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 122.3 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.4 botocore-1.38.4 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/video"    # Directory of MSRVTT raw video

# %%
# import pandas as pd

# # Load training dataset
# train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
# df = pd.read_csv(train_path)

# print("Size: ", len(df))
# print("Column names", df.columns.tolist())
# display(df.head())

# # Choose a subset
# def sample_subset(df, frac=0.1, random_state=42):
#     return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# # Set fraction to 0.01
# subset_df = sample_subset(df, frac=0.1)
# print("Size of subset：", len(subset_df))
# display(subset_df.head())

# # Save the subset
# subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
# subset_df.to_csv(subset_path, index=False)

# print("Subset CSV saved to:", subset_path)

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA L4

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-28 22:24:40--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.70, 2620:1ec:bdf::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt’
#
# ViT-B-32.pt         100%[===================>] 337.58M  15.6MB/s    in 17s
#
# 2025-04-28 22:24:57 (19.7 MB/s) - ‘./modules/ViT-B-32.pt’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# Already up to date.

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=9498c042b24cf5969fdb159dc7167087b97508c177a9014a9f73de86d77d9814
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
# %%bash
# export DATA_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"
# export VIDEO_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/video"
#
# python /content/CLIP_video/main_task_retrieval.py \
#   --do_train \
#   --num_thread_reader 8 \
#   --epochs 20 \
#   --batch_size 64 \
#   --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
#   --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
#   --data_path  "$DATA_PATH"/MSRVTT_data.json \
#   --features_path "$VIDEO_PATH" \
#   --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
#   --lr 1e-4 \
#   --max_words 32 \
#   --max_frames 8 \
#   --batch_size_val 8 \
#   --datatype msrvtt \
#   --expand_msrvtt_sentences \
#   --feature_framerate 1 \
#   --coef_lr 1e-3 \
#   --freeze_layer_num 6 \
#   --slice_framepos 8 \
#   --loose_type \
#   --linear_patch 2d \
#   --sim_header seqLSTM \
#   --pretrained_clip_name ViT-B/32 \
#   --fp16 \
#   --fp16_opt_level O1
# Out:
# 124/125
# 04/28/2025 22:25:07 - INFO -   Effective parameters:
# 04/28/2025 22:25:07 - INFO -     <<< batch_size: 64
# 04/28/2025 22:25:07 - INFO -     <<< batch_size_val: 8
# 04/28/2025 22:25:07 - INFO -     <<< cache_dir:
# 04/28/2025 22:25:07 - INFO -     <<< coef_lr: 0.001
# 04/28/2025 22:25:07 - INFO -     <<< cross_model: cross-base
# 04/28/2025 22:25:07 - INFO -     <<< cross_num_hidden_layers: 4
# 04/28/2025 22:25:07 - INFO -     <<< data_path: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_data.json
# 04/28/2025 22:25:07 - INFO -     <<< datatype: msrvtt
# 04/28/2025 22:25:07 - INFO -     <<< do_eval: False
# 04/28/2025 22:25:07 - INFO -     <<< do_lower_case: False
# 04/28/2025 22:25:07 - INFO -     <<< do_pretrain: False
# 04/28/2025 22:25:07 - INFO -     <<< do_train: True
# 04/28/2025 22:25:07 - INFO -     <<< epochs: 20
# 04/28/2025 22:25:07 - INFO -     <<< eval_frame_order: 0
# 04/28/2025 22:25:07 - INFO -     <<< expand_msrvtt_sentences: True
# 04/28/2025 22:25:07 - INFO -     <<< feature_framerate: 1
# 04/28/2025 22:25:07 - INFO -     <<< features_path: /content/drive/MyDrive/IDL/IDL Project/Data/video
# 04/28/2025 22:25:07 - INFO -     <<< fp16: True
# 04/28/2025 22:25:07 - INFO -     <<< fp16_opt_level: O1
# 04/28/2025 22:25:07 - INFO -     <<< freeze_layer_num: 6
# 04/28/2025 22:25:07 - INFO -     <<< gradient_accumulation_steps: 1
# 04/28/2025 22:25:07 - INFO -     <<< hard_negative_rate: 0.5
# 04/28/2025 22:25:07 - INFO -     <<< init_model: None
# 04/28/2025 22:25:07 - INFO -     <<< linear_patch: 2d
# 04/28/2025 22:25:07 - INFO -     <<< loose_type: True
# 04/28/2025 22:25:07 - INFO -     <<< lr: 0.0001
# 04/28/2025 22:25:07 - INFO -     <<< lr_decay: 0.9
# 04/28/2025 22:25:07 - INFO -     <<< margin: 0.1
# 04/28/2025 22:25:07 - INFO -     <<< max_frames: 8
# 04/28/2025 22:25:07 - INFO -     <<< max_words: 32
# 04/28/2025 22:25:07 - INFO -     <<< n_display: 100
# 04/28/2025 22:25:07 - INFO -     <<< n_gpu: 1
# 04/28/2025 22:25:07 - INFO -     <<< n_pair: 1
# 04/28/2025 22:25:07 - INFO -     <<< negative_weighting: 1
# 04/28/2025 22:25:07 - INFO -     <<< num_thread_reader: 8
# 04/28/2025 22:25:07 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/28/2025 22:25:07 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/28/2025 22:25:07 - INFO -     <<< rank: 0
# 04/28/2025 22:25:07 - INFO -     <<< resume_model: None
# 04/28/2025 22:25:07 - INFO -     <<< sampled_use_mil: False
# 04/28/2025 22:25:07 - INFO -     <<< seed: 42
# 04/28/2025 22:25:07 - INFO -     <<< sim_header: seqLSTM
# 04/28/2025 22:25:07 - INFO -     <<< slice_framepos: 8
# 04/28/2025 22:25:07 - INFO -     <<< task_type: retrieval
# 04/28/2025 22:25:07 - INFO -     <<< text_num_hidden_layers: 12
# 04/28/2025 22:25:07 - INFO -     <<< train_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/28/2025 22:25:07 - INFO -     <<< train_frame_order: 0
# 04/28/2025 22:25:07 - INFO -     <<< use_mil: False
# 04/28/2025 22:25:07 - INFO -     <<< val_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/28/2025 22:25:07 - INFO -     <<< video_dim: 1024
# 04/28/2025 22:25:07 - INFO -     <<< visual_num_hidden_layers: 12
# 04/28/2025 22:25:07 - INFO -     <<< warmup_proportion: 0.1
# 04/28/2025 22:25:07 - INFO -     <<< world_size: 1
# 04/28/2025 22:25:07 - INFO -   device: cuda n_gpu: 1
# 100%|███████████████████████████████████████| 354M/354M [00:15<00:00, 22.1MiB/s]
# 04/28/2025 22:25:25 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/28/2025 22:25:25 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/28/2025 22:25:25 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/28/2025 22:25:25 - WARNING -   Stage-One:True, Stage-Two:False
# 04/28/2025 22:25:25 - WARNING -   Test retrieval by loose type.
# 04/28/2025 22:25:25 - WARNING -   	 embed_dim: 512
# 04/28/2025 22:25:25 - WARNING -   	 image_resolution: 224
# 04/28/2025 22:25:25 - WARNING -   	 vision_layers: 12
# 04/28/2025 22:25:25 - WARNING -   	 vision_width: 768
# 04/28/2025 22:25:25 - WARNING -   	 vision_patch_size: 32
# 04/28/2025 22:25:25 - WARNING -   	 context_length: 77
# 04/28/2025 22:25:25 - WARNING -   	 vocab_size: 49408
# 04/28/2025 22:25:25 - WARNING -   	 transformer_width: 512
# 04/28/2025 22:25:25 - WARNING -   	 transformer_heads: 8
# 04/28/2025 22:25:25 - WARNING -   	 transformer_layers: 12
# 04/28/2025 22:25:25 - WARNING -   		 linear_patch: 2d
# 04/28/2025 22:25:25 - WARNING -   	 cut_top_layer: 0
# 04/28/2025 22:25:27 - WARNING -   	 sim_header: seqLSTM
# 04/28/2025 22:25:31 - INFO -   --------------------
# 04/28/2025 22:25:31 - INFO -   Weights of CLIP4Clip not initialized from pretrained model:
#    lstm_visual.weight_ih_l0
#    lstm_visual.weight_hh_l0
#    lstm_visual.bias_ih_l0
#    lstm_visual.bias_hh_l0
# 04/28/2025 22:25:31 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/28/2025 22:25:35 - INFO -   ***** Running test *****
# 04/28/2025 22:25:35 - INFO -     Num examples = 1000
# 04/28/2025 22:25:35 - INFO -     Batch size = 8
# 04/28/2025 22:25:35 - INFO -     Num steps = 125
# 04/28/2025 22:25:35 - INFO -   ***** Running val *****
# 04/28/2025 22:25:35 - INFO -     Num examples = 1000
# 04/28/2025 22:25:39 - INFO -   ***** Running training *****
# 04/28/2025 22:25:39 - INFO -     Num examples = 18000
# 04/28/2025 22:25:39 - INFO -     Batch size = 64
# 04/28/2025 22:25:39 - INFO -     Num steps = 5620
# Epoch 1:  35%|███▌      | 99/281 [08:18<12:32,  4.13s/it, loss=1.2] 04/28/2025 22:33:57 - INFO -   Epoch: 1/20, Step: 100/281, Lr: , Loss: 1.202614, Time/step: 4.982565
# Epoch 1:  71%|███████   | 199/281 [15:21<04:36,  3.37s/it, loss=0.933]04/28/2025 22:41:01 - INFO -   Epoch: 1/20, Step: 200/281, Lr: , Loss: 0.932964, Time/step: 4.232463
# Epoch 1: 100%|██████████| 281/281 [20:57<00:00,  4.47s/it, loss=0.72]
# 04/28/2025 22:46:37 - INFO -   Epoch 1/20 Finished, Train Loss: 1.195904
# 04/28/2025 22:46:38 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/28/2025 22:46:38 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100%|██████████| 125/125 [01:40<00:00,  1.24it/s]
# 04/28/2025 22:48:38 - INFO -   sim matrix size: 1000, 1000
# 04/28/2025 22:48:38 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/28/2025 22:48:38 - INFO -   Text-to-Video:
# 04/28/2025 22:48:38 - INFO -   	>>>  R@1: 36.7 - R@5: 61.9 - R@10: 72.9 - Median R: 3.0 - Mean R: 21.4
# 04/28/2025 22:48:38 - INFO -   Video-to-Text:
# 04/28/2025 22:48:38 - INFO -   	>>>  V2T$R@1: 36.3 - V2T$R@5: 62.2 - V2T$R@10: 75.7 - V2T$Median R: 3.0 - V2T$Mean R: 19.8
# 04/28/2025 22:48:38 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 36.7000
# Epoch 2:   6%|▋         | 18/281 [01:49<33:46,  7.71s/it, loss=0.623]04/28/2025 22:50:27 - INFO -   Epoch: 2/20, Step: 19/281, Lr: , Loss: 0.622663, Time/step: 1.096796
# Epoch 2:  42%|████▏     | 118/281 [08:59<08:34,  3.16s/it, loss=0.704]04/28/2025 22:57:37 - INFO -   Epoch: 2/20, Step: 119/281, Lr: , Loss: 0.704401, Time/step: 4.299405
# Epoch 2:  78%|███████▊  | 218/281 [16:13<08:36,  8.21s/it, loss=0.546]04/28/2025 23:04:51 - INFO -   Epoch: 2/20, Step: 219/281, Lr: , Loss: 0.546516, Time/step: 4.340562
# Epoch 2: 100%|██████████| 281/281 [20:11<00:00,  4.31s/it, loss=0.584]
# 04/28/2025 23:08:50 - INFO -   Epoch 2/20 Finished, Train Loss: 0.706255
# 04/28/2025 23:08:51 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/28/2025 23:08:51 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.76it/s]
# 04/28/2025 23:10:21 - INFO -   sim matrix size: 1000, 1000
# 04/28/2025 23:10:21 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/28/2025 23:10:21 - INFO -   Text-to-Video:
# 04/28/2025 23:10:21 - INFO -   	>>>  R@1: 37.1 - R@5: 61.6 - R@10: 73.5 - Median R: 3.0 - Mean R: 20.0
# 04/28/2025 23:10:21 - INFO -   Video-to-Text:
# 04/28/2025 23:10:21 - INFO -   	>>>  V2T$R@1: 36.0 - V2T$R@5: 62.5 - V2T$R@10: 73.6 - V2T$Median R: 3.0 - V2T$Mean R: 16.9
# 04/28/2025 23:10:21 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 37.1000
# Epoch 3:  13%|█▎        | 37/281 [03:01<15:12,  3.74s/it, loss=0.389]04/28/2025 23:13:23 - INFO -   Epoch: 3/20, Step: 38/281, Lr: , Loss: 0.388590, Time/step: 1.820536
# Epoch 3:  49%|████▉     | 137/281 [10:23<11:07,  4.64s/it, loss=0.789]04/28/2025 23:20:45 - INFO -   Epoch: 3/20, Step: 138/281, Lr: , Loss: 0.789068, Time/step: 4.413730
# Epoch 3:  84%|████████▍ | 237/281 [17:25<02:24,  3.29s/it, loss=0.493]04/28/2025 23:27:47 - INFO -   Epoch: 3/20, Step: 238/281, Lr: , Loss: 0.493048, Time/step: 4.222925
# Epoch 3: 100%|██████████| 281/281 [20:10<00:00,  4.31s/it, loss=0.545]
# 04/28/2025 23:30:32 - INFO -   Epoch 3/20 Finished, Train Loss: 0.491327
# 04/28/2025 23:30:33 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/28/2025 23:30:33 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/28/2025 23:32:03 - INFO -   sim matrix size: 1000, 1000
# 04/28/2025 23:32:03 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/28/2025 23:32:03 - INFO -   Text-to-Video:
# 04/28/2025 23:32:03 - INFO -   	>>>  R@1: 37.2 - R@5: 62.8 - R@10: 74.1 - Median R: 3.0 - Mean R: 20.5
# 04/28/2025 23:32:03 - INFO -   Video-to-Text:
# 04/28/2025 23:32:03 - INFO -   	>>>  V2T$R@1: 35.9 - V2T$R@5: 63.5 - V2T$R@10: 75.5 - V2T$Median R: 3.0 - V2T$Mean R: 17.5
# 04/28/2025 23:32:04 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 37.2000
# Epoch 4:  20%|█▉        | 56/281 [04:29<08:22,  2.23s/it, loss=0.318]04/28/2025 23:36:34 - INFO -   Epoch: 4/20, Step: 57/281, Lr: , Loss: 0.317647, Time/step: 2.700850
# Epoch 4:  56%|█████▌    | 156/281 [11:34<08:11,  3.93s/it, loss=0.366]04/28/2025 23:43:38 - INFO -   Epoch: 4/20, Step: 157/281, Lr: , Loss: 0.365781, Time/step: 4.246648
# Epoch 4:  91%|█████████ | 256/281 [19:03<00:56,  2.27s/it, loss=0.386]04/28/2025 23:51:07 - INFO -   Epoch: 4/20, Step: 257/281, Lr: , Loss: 0.386298, Time/step: 4.485613
# Epoch 4: 100%|██████████| 281/281 [20:12<00:00,  4.32s/it, loss=0.429]
# 04/28/2025 23:52:17 - INFO -   Epoch 4/20 Finished, Train Loss: 0.333910
# 04/28/2025 23:52:18 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/28/2025 23:52:18 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/28/2025 23:53:48 - INFO -   sim matrix size: 1000, 1000
# 04/28/2025 23:53:48 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/28/2025 23:53:48 - INFO -   Text-to-Video:
# 04/28/2025 23:53:48 - INFO -   	>>>  R@1: 37.9 - R@5: 63.8 - R@10: 74.2 - Median R: 3.0 - Mean R: 21.0
# 04/28/2025 23:53:48 - INFO -   Video-to-Text:
# 04/28/2025 23:53:48 - INFO -   	>>>  V2T$R@1: 35.4 - V2T$R@5: 62.1 - V2T$R@10: 72.2 - V2T$Median R: 3.0 - V2T$Mean R: 19.2
# 04/28/2025 23:53:48 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 37.9000
# Epoch 5:  27%|██▋       | 75/281 [05:43<14:39,  4.27s/it, loss=0.151]04/28/2025 23:59:31 - INFO -   Epoch: 5/20, Step: 76/281, Lr: , Loss: 0.151410, Time/step: 3.433797
# Epoch 5:  62%|██████▏   | 175/281 [12:44<03:28,  1.97s/it, loss=0.178]04/29/2025 00:06:32 - INFO -   Epoch: 5/20, Step: 176/281, Lr: , Loss: 0.178209, Time/step: 4.209133
# Epoch 5:  98%|█████████▊| 275/281 [20:02<00:20,  3.38s/it, loss=0.25] 04/29/2025 00:13:50 - INFO -   Epoch: 5/20, Step: 276/281, Lr: , Loss: 0.249573, Time/step: 4.380469
# Epoch 5: 100%|██████████| 281/281 [20:09<00:00,  4.31s/it, loss=0.166]
# 04/29/2025 00:13:58 - INFO -   Epoch 5/20 Finished, Train Loss: 0.261356
# 04/29/2025 00:13:59 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/29/2025 00:13:59 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/29/2025 00:15:30 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 00:15:30 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 00:15:30 - INFO -   Text-to-Video:
# 04/29/2025 00:15:30 - INFO -   	>>>  R@1: 37.9 - R@5: 63.2 - R@10: 73.6 - Median R: 3.0 - Mean R: 22.1
# 04/29/2025 00:15:30 - INFO -   Video-to-Text:
# 04/29/2025 00:15:30 - INFO -   	>>>  V2T$R@1: 33.5 - V2T$R@5: 61.1 - V2T$R@10: 72.7 - V2T$Median R: 3.0 - V2T$Mean R: 18.5
# 04/29/2025 00:15:30 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 6:  33%|███▎      | 94/281 [07:06<07:31,  2.41s/it, loss=0.114]04/29/2025 00:22:37 - INFO -   Epoch: 6/20, Step: 95/281, Lr: , Loss: 0.113846, Time/step: 4.269937
# Epoch 6:  69%|██████▉   | 194/281 [14:24<09:32,  6.58s/it, loss=0.329]04/29/2025 00:29:55 - INFO -   Epoch: 6/20, Step: 195/281, Lr: , Loss: 0.328576, Time/step: 4.378359
# Epoch 6: 100%|██████████| 281/281 [20:11<00:00,  4.31s/it, loss=0.354]
# 04/29/2025 00:35:42 - INFO -   Epoch 6/20 Finished, Train Loss: 0.220589
# 04/29/2025 00:35:42 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.5
# 04/29/2025 00:35:42 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.5
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/29/2025 00:37:13 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 00:37:13 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 00:37:13 - INFO -   Text-to-Video:
# 04/29/2025 00:37:13 - INFO -   	>>>  R@1: 36.7 - R@5: 63.4 - R@10: 74.2 - Median R: 3.0 - Mean R: 21.9
# 04/29/2025 00:37:13 - INFO -   Video-to-Text:
# 04/29/2025 00:37:13 - INFO -   	>>>  V2T$R@1: 35.1 - V2T$R@5: 62.1 - V2T$R@10: 73.2 - V2T$Median R: 3.0 - V2T$Mean R: 19.2
# 04/29/2025 00:37:13 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 7:   5%|▍         | 13/281 [01:18<16:10,  3.62s/it, loss=0.117]04/29/2025 00:38:31 - INFO -   Epoch: 7/20, Step: 14/281, Lr: , Loss: 0.116835, Time/step: 0.782175
# Epoch 7:  40%|████      | 113/281 [08:30<19:20,  6.91s/it, loss=0.171]04/29/2025 00:45:43 - INFO -   Epoch: 7/20, Step: 114/281, Lr: , Loss: 0.170953, Time/step: 4.324536
# Epoch 7:  76%|███████▌  | 213/281 [15:39<03:29,  3.08s/it, loss=0.238]04/29/2025 00:52:52 - INFO -   Epoch: 7/20, Step: 214/281, Lr: , Loss: 0.237977, Time/step: 4.289072
# Epoch 7: 100%|██████████| 281/281 [20:12<00:00,  4.32s/it, loss=0.203]
# 04/29/2025 00:57:26 - INFO -   Epoch 7/20 Finished, Train Loss: 0.191260
# 04/29/2025 00:57:26 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.6
# 04/29/2025 00:57:26 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.6
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.73it/s]
# 04/29/2025 00:58:58 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 00:58:58 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 00:58:58 - INFO -   Text-to-Video:
# 04/29/2025 00:58:58 - INFO -   	>>>  R@1: 36.5 - R@5: 62.1 - R@10: 73.4 - Median R: 3.0 - Mean R: 22.8
# 04/29/2025 00:58:58 - INFO -   Video-to-Text:
# 04/29/2025 00:58:58 - INFO -   	>>>  V2T$R@1: 36.4 - V2T$R@5: 61.7 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/29/2025 00:58:58 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 8:  11%|█▏        | 32/281 [02:55<07:08,  1.72s/it, loss=0.199]04/29/2025 01:01:54 - INFO -   Epoch: 8/20, Step: 33/281, Lr: , Loss: 0.198600, Time/step: 1.757720
# Epoch 8:  47%|████▋     | 132/281 [09:56<10:07,  4.08s/it, loss=0.175]04/29/2025 01:08:54 - INFO -   Epoch: 8/20, Step: 133/281, Lr: , Loss: 0.175136, Time/step: 4.206293
# Epoch 8:  83%|████████▎ | 232/281 [17:11<03:55,  4.80s/it, loss=0.241]04/29/2025 01:16:09 - INFO -   Epoch: 8/20, Step: 233/281, Lr: , Loss: 0.241243, Time/step: 4.349592
# Epoch 8: 100%|██████████| 281/281 [20:08<00:00,  4.30s/it, loss=0.0755]
# 04/29/2025 01:19:07 - INFO -   Epoch 8/20 Finished, Train Loss: 0.168242
# 04/29/2025 01:19:08 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.7
# 04/29/2025 01:19:08 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.7
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/29/2025 01:20:38 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 01:20:38 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 01:20:38 - INFO -   Text-to-Video:
# 04/29/2025 01:20:38 - INFO -   	>>>  R@1: 36.7 - R@5: 61.7 - R@10: 73.9 - Median R: 3.0 - Mean R: 22.5
# 04/29/2025 01:20:38 - INFO -   Video-to-Text:
# 04/29/2025 01:20:38 - INFO -   	>>>  V2T$R@1: 33.8 - V2T$R@5: 61.1 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/29/2025 01:20:38 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 9:  18%|█▊        | 51/281 [04:12<22:34,  5.89s/it, loss=0.0864]04/29/2025 01:24:51 - INFO -   Epoch: 9/20, Step: 52/281, Lr: , Loss: 0.086440, Time/step: 2.526728
# Epoch 9:  54%|█████▎    | 151/281 [11:06<04:17,  1.98s/it, loss=0.222]04/29/2025 01:31:45 - INFO -   Epoch: 9/20, Step: 152/281, Lr: , Loss: 0.221981, Time/step: 4.140256
# Epoch 9:  89%|████████▉ | 251/281 [18:24<02:24,  4.82s/it, loss=0.176]04/29/2025 01:39:03 - INFO -   Epoch: 9/20, Step: 252/281, Lr: , Loss: 0.176446, Time/step: 4.380012
# Epoch 9: 100%|██████████| 281/281 [20:08<00:00,  4.30s/it, loss=0.216]
# 04/29/2025 01:40:47 - INFO -   Epoch 9/20 Finished, Train Loss: 0.156283
# 04/29/2025 01:40:48 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.8
# 04/29/2025 01:40:48 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.8
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.73it/s]
# 04/29/2025 01:42:19 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 01:42:19 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 01:42:19 - INFO -   Text-to-Video:
# 04/29/2025 01:42:19 - INFO -   	>>>  R@1: 36.5 - R@5: 62.7 - R@10: 73.2 - Median R: 3.0 - Mean R: 23.2
# 04/29/2025 01:42:19 - INFO -   Video-to-Text:
# 04/29/2025 01:42:19 - INFO -   	>>>  V2T$R@1: 34.1 - V2T$R@5: 61.3 - V2T$R@10: 72.4 - V2T$Median R: 3.0 - V2T$Mean R: 19.7
# 04/29/2025 01:42:19 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 10:  25%|██▍       | 70/281 [05:20<08:43,  2.48s/it, loss=0.0376]04/29/2025 01:47:40 - INFO -   Epoch: 10/20, Step: 71/281, Lr: , Loss: 0.037634, Time/step: 3.203349
# Epoch 10:  60%|██████    | 170/281 [12:38<13:32,  7.32s/it, loss=0.288]04/29/2025 01:54:59 - INFO -   Epoch: 10/20, Step: 171/281, Lr: , Loss: 0.287662, Time/step: 4.387392
# Epoch 10:  96%|█████████▌| 270/281 [19:38<00:48,  4.41s/it, loss=0.145]04/29/2025 02:01:59 - INFO -   Epoch: 10/20, Step: 271/281, Lr: , Loss: 0.145187, Time/step: 4.200349
# Epoch 10: 100%|██████████| 281/281 [20:07<00:00,  4.30s/it, loss=0.154]
# 04/29/2025 02:02:28 - INFO -   Epoch 10/20 Finished, Train Loss: 0.146919
# 04/29/2025 02:02:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.9
# 04/29/2025 02:02:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.9
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.76it/s]
# 04/29/2025 02:03:59 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 02:03:59 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 02:03:59 - INFO -   Text-to-Video:
# 04/29/2025 02:03:59 - INFO -   	>>>  R@1: 36.3 - R@5: 63.2 - R@10: 72.8 - Median R: 3.0 - Mean R: 23.4
# 04/29/2025 02:03:59 - INFO -   Video-to-Text:
# 04/29/2025 02:03:59 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 60.6 - V2T$R@10: 72.1 - V2T$Median R: 3.0 - V2T$Mean R: 20.0
# 04/29/2025 02:03:59 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 11:  32%|███▏      | 89/281 [06:54<26:29,  8.28s/it, loss=0.156] 04/29/2025 02:10:54 - INFO -   Epoch: 11/20, Step: 90/281, Lr: , Loss: 0.155697, Time/step: 4.146761
# Epoch 11:  67%|██████▋   | 189/281 [13:51<04:20,  2.83s/it, loss=0.135] 04/29/2025 02:17:51 - INFO -   Epoch: 11/20, Step: 190/281, Lr: , Loss: 0.135058, Time/step: 4.171325
# Epoch 11: 100%|██████████| 281/281 [20:09<00:00,  4.30s/it, loss=0.138]
# 04/29/2025 02:24:08 - INFO -   Epoch 11/20 Finished, Train Loss: 0.132838
# 04/29/2025 02:24:09 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.10
# 04/29/2025 02:24:09 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.10
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/29/2025 02:25:39 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 02:25:40 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 02:25:40 - INFO -   Text-to-Video:
# 04/29/2025 02:25:40 - INFO -   	>>>  R@1: 36.6 - R@5: 63.1 - R@10: 72.9 - Median R: 3.0 - Mean R: 23.0
# 04/29/2025 02:25:40 - INFO -   Video-to-Text:
# 04/29/2025 02:25:40 - INFO -   	>>>  V2T$R@1: 34.6 - V2T$R@5: 62.3 - V2T$R@10: 73.6 - V2T$Median R: 3.0 - V2T$Mean R: 19.7
# 04/29/2025 02:25:40 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 12:   3%|▎         | 8/281 [01:08<09:02,  1.99s/it, loss=0.0704]04/29/2025 02:26:48 - INFO -   Epoch: 12/20, Step: 9/281, Lr: , Loss: 0.070403, Time/step: 0.683912
# Epoch 12:  38%|███▊      | 108/281 [08:10<12:24,  4.30s/it, loss=0.164]04/29/2025 02:33:51 - INFO -   Epoch: 12/20, Step: 109/281, Lr: , Loss: 0.163590, Time/step: 4.225599
# Epoch 12:  74%|███████▍  | 208/281 [15:21<02:12,  1.81s/it, loss=0.237]04/29/2025 02:41:01 - INFO -   Epoch: 12/20, Step: 209/281, Lr: , Loss: 0.237383, Time/step: 4.304263
# Epoch 12: 100%|██████████| 281/281 [20:08<00:00,  4.30s/it, loss=0.104]
# 04/29/2025 02:45:49 - INFO -   Epoch 12/20 Finished, Train Loss: 0.121074
# 04/29/2025 02:45:50 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.11
# 04/29/2025 02:45:50 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.11
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.78it/s]
# 04/29/2025 02:47:19 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 02:47:19 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 02:47:19 - INFO -   Text-to-Video:
# 04/29/2025 02:47:19 - INFO -   	>>>  R@1: 36.4 - R@5: 63.0 - R@10: 73.1 - Median R: 3.0 - Mean R: 23.0
# 04/29/2025 02:47:19 - INFO -   Video-to-Text:
# 04/29/2025 02:47:19 - INFO -   	>>>  V2T$R@1: 33.9 - V2T$R@5: 61.7 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.8
# 04/29/2025 02:47:19 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 13:  10%|▉         | 27/281 [02:21<24:36,  5.81s/it, loss=0.152]04/29/2025 02:49:41 - INFO -   Epoch: 13/20, Step: 28/281, Lr: , Loss: 0.152461, Time/step: 1.419316
# Epoch 13:  45%|████▌     | 127/281 [09:17<06:30,  2.54s/it, loss=0.0943]04/29/2025 02:56:38 - INFO -   Epoch: 13/20, Step: 128/281, Lr: , Loss: 0.094293, Time/step: 4.160353
# Epoch 13:  81%|████████  | 227/281 [16:28<02:24,  2.68s/it, loss=0.144] 04/29/2025 03:03:49 - INFO -   Epoch: 13/20, Step: 228/281, Lr: , Loss: 0.144262, Time/step: 4.311125
# Epoch 13: 100%|██████████| 281/281 [20:07<00:00,  4.30s/it, loss=0.168]
# 04/29/2025 03:07:27 - INFO -   Epoch 13/20 Finished, Train Loss: 0.108031
# 04/29/2025 03:07:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.12
# 04/29/2025 03:07:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.12
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/29/2025 03:08:58 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 03:08:58 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 03:08:58 - INFO -   Text-to-Video:
# 04/29/2025 03:08:58 - INFO -   	>>>  R@1: 36.2 - R@5: 63.5 - R@10: 72.6 - Median R: 3.0 - Mean R: 22.9
# 04/29/2025 03:08:58 - INFO -   Video-to-Text:
# 04/29/2025 03:08:58 - INFO -   	>>>  V2T$R@1: 35.2 - V2T$R@5: 61.7 - V2T$R@10: 72.6 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/29/2025 03:08:58 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 14:  16%|█▋        | 46/281 [03:38<09:38,  2.46s/it, loss=0.126] 04/29/2025 03:12:36 - INFO -   Epoch: 14/20, Step: 47/281, Lr: , Loss: 0.125989, Time/step: 2.183229
# Epoch 14:  52%|█████▏    | 146/281 [11:06<15:26,  6.86s/it, loss=0.12] 04/29/2025 03:20:05 - INFO -   Epoch: 14/20, Step: 147/281, Lr: , Loss: 0.119908, Time/step: 4.482778
# Epoch 14:  88%|████████▊ | 246/281 [18:04<01:20,  2.31s/it, loss=0.129]04/29/2025 03:27:03 - INFO -   Epoch: 14/20, Step: 247/281, Lr: , Loss: 0.128455, Time/step: 4.185609
# Epoch 14: 100%|██████████| 281/281 [20:10<00:00,  4.31s/it, loss=0.125]
# 04/29/2025 03:29:09 - INFO -   Epoch 14/20 Finished, Train Loss: 0.104541
# 04/29/2025 03:29:10 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.13
# 04/29/2025 03:29:10 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.13
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.78it/s]
# 04/29/2025 03:30:40 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 03:30:40 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 03:30:40 - INFO -   Text-to-Video:
# 04/29/2025 03:30:40 - INFO -   	>>>  R@1: 36.8 - R@5: 63.6 - R@10: 72.9 - Median R: 3.0 - Mean R: 22.8
# 04/29/2025 03:30:40 - INFO -   Video-to-Text:
# 04/29/2025 03:30:40 - INFO -   	>>>  V2T$R@1: 35.1 - V2T$R@5: 62.4 - V2T$R@10: 73.7 - V2T$Median R: 3.0 - V2T$Mean R: 19.4
# 04/29/2025 03:30:40 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 15:  23%|██▎       | 65/281 [05:21<35:04,  9.74s/it, loss=0.0803]04/29/2025 03:36:01 - INFO -   Epoch: 15/20, Step: 66/281, Lr: , Loss: 0.080255, Time/step: 3.212794
# Epoch 15:  59%|█████▊    | 165/281 [12:07<05:12,  2.69s/it, loss=0.0198]04/29/2025 03:42:48 - INFO -   Epoch: 15/20, Step: 166/281, Lr: , Loss: 0.019842, Time/step: 4.065613
# Epoch 15:  94%|█████████▍| 265/281 [19:27<02:10,  8.17s/it, loss=0.0195]04/29/2025 03:50:07 - INFO -   Epoch: 15/20, Step: 266/281, Lr: , Loss: 0.019452, Time/step: 4.397755
# Epoch 15: 100%|██████████| 281/281 [20:06<00:00,  4.29s/it, loss=0.185]
# 04/29/2025 03:50:46 - INFO -   Epoch 15/20 Finished, Train Loss: 0.102109
# 04/29/2025 03:50:47 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.14
# 04/29/2025 03:50:47 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.14
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.78it/s]
# 04/29/2025 03:52:17 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 03:52:17 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 03:52:17 - INFO -   Text-to-Video:
# 04/29/2025 03:52:17 - INFO -   	>>>  R@1: 36.4 - R@5: 63.5 - R@10: 72.9 - Median R: 3.0 - Mean R: 22.8
# 04/29/2025 03:52:17 - INFO -   Video-to-Text:
# 04/29/2025 03:52:17 - INFO -   	>>>  V2T$R@1: 34.8 - V2T$R@5: 62.1 - V2T$R@10: 73.0 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 03:52:17 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 16:  30%|██▉       | 84/281 [06:31<12:22,  3.77s/it, loss=0.0774]04/29/2025 03:58:48 - INFO -   Epoch: 16/20, Step: 85/281, Lr: , Loss: 0.077396, Time/step: 3.914337
# Epoch 16:  65%|██████▌   | 184/281 [13:35<03:04,  1.90s/it, loss=0.0657]04/29/2025 04:05:53 - INFO -   Epoch: 16/20, Step: 185/281, Lr: , Loss: 0.065673, Time/step: 4.244965
# Epoch 16: 100%|██████████| 281/281 [20:06<00:00,  4.29s/it, loss=0.144]
# 04/29/2025 04:12:24 - INFO -   Epoch 16/20 Finished, Train Loss: 0.105768
# 04/29/2025 04:12:25 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.15
# 04/29/2025 04:12:25 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.15
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/29/2025 04:13:56 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 04:13:56 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 04:13:56 - INFO -   Text-to-Video:
# 04/29/2025 04:13:56 - INFO -   	>>>  R@1: 36.4 - R@5: 63.5 - R@10: 72.8 - Median R: 3.0 - Mean R: 22.8
# 04/29/2025 04:13:56 - INFO -   Video-to-Text:
# 04/29/2025 04:13:56 - INFO -   	>>>  V2T$R@1: 34.8 - V2T$R@5: 62.1 - V2T$R@10: 73.5 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 04:13:56 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 17:   1%|          | 3/281 [00:37<39:46,  8.58s/it, loss=0.0807]04/29/2025 04:14:34 - INFO -   Epoch: 17/20, Step: 4/281, Lr: , Loss: 0.080725, Time/step: 0.377256
# Epoch 17:  37%|███▋      | 103/281 [07:33<06:11,  2.09s/it, loss=0.0809]04/29/2025 04:21:30 - INFO -   Epoch: 17/20, Step: 104/281, Lr: , Loss: 0.080906, Time/step: 4.162657
# Epoch 17:  72%|███████▏  | 203/281 [15:03<09:38,  7.42s/it, loss=0.155] 04/29/2025 04:28:59 - INFO -   Epoch: 17/20, Step: 204/281, Lr: , Loss: 0.155175, Time/step: 4.492324
# Epoch 17: 100%|██████████| 281/281 [20:06<00:00,  4.29s/it, loss=0.0517]
# 04/29/2025 04:34:03 - INFO -   Epoch 17/20 Finished, Train Loss: 0.098810
# 04/29/2025 04:34:04 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.16
# 04/29/2025 04:34:04 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.16
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.76it/s]
# 04/29/2025 04:35:34 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 04:35:34 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 04:35:34 - INFO -   Text-to-Video:
# 04/29/2025 04:35:34 - INFO -   	>>>  R@1: 36.6 - R@5: 63.5 - R@10: 72.7 - Median R: 3.0 - Mean R: 22.9
# 04/29/2025 04:35:34 - INFO -   Video-to-Text:
# 04/29/2025 04:35:34 - INFO -   	>>>  V2T$R@1: 34.4 - V2T$R@5: 62.0 - V2T$R@10: 73.4 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 04:35:34 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 18:   8%|▊         | 22/281 [01:53<11:14,  2.60s/it, loss=0.0415]04/29/2025 04:37:28 - INFO -   Epoch: 18/20, Step: 23/281, Lr: , Loss: 0.041456, Time/step: 1.136175
# Epoch 18:  43%|████▎     | 122/281 [09:16<15:16,  5.76s/it, loss=0.157]04/29/2025 04:44:51 - INFO -   Epoch: 18/20, Step: 123/281, Lr: , Loss: 0.157125, Time/step: 4.427933
# Epoch 18:  79%|███████▉  | 222/281 [16:16<02:45,  2.80s/it, loss=0.2]   04/29/2025 04:51:51 - INFO -   Epoch: 18/20, Step: 223/281, Lr: , Loss: 0.199867, Time/step: 4.207005
# Epoch 18: 100%|██████████| 281/281 [20:06<00:00,  4.29s/it, loss=0.175]
# 04/29/2025 04:55:41 - INFO -   Epoch 18/20 Finished, Train Loss: 0.097691
# 04/29/2025 04:55:42 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.17
# 04/29/2025 04:55:42 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.17
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/29/2025 04:57:13 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 04:57:13 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 04:57:13 - INFO -   Text-to-Video:
# 04/29/2025 04:57:13 - INFO -   	>>>  R@1: 36.6 - R@5: 63.6 - R@10: 72.7 - Median R: 3.0 - Mean R: 22.9
# 04/29/2025 04:57:13 - INFO -   Video-to-Text:
# 04/29/2025 04:57:13 - INFO -   	>>>  V2T$R@1: 34.4 - V2T$R@5: 62.0 - V2T$R@10: 73.6 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 04:57:13 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 19:  15%|█▍        | 41/281 [03:24<27:43,  6.93s/it, loss=0.0702]04/29/2025 05:00:38 - INFO -   Epoch: 19/20, Step: 42/281, Lr: , Loss: 0.070190, Time/step: 2.042486
# Epoch 19:  50%|█████     | 141/281 [10:32<10:01,  4.30s/it, loss=0.0603]04/29/2025 05:07:46 - INFO -   Epoch: 19/20, Step: 142/281, Lr: , Loss: 0.060317, Time/step: 4.285175
# Epoch 19:  86%|████████▌ | 241/281 [17:35<03:03,  4.58s/it, loss=0.0876]04/29/2025 05:14:49 - INFO -   Epoch: 19/20, Step: 242/281, Lr: , Loss: 0.087628, Time/step: 4.224754
# Epoch 19: 100%|██████████| 281/281 [20:07<00:00,  4.30s/it, loss=0.14]
# 04/29/2025 05:17:21 - INFO -   Epoch 19/20 Finished, Train Loss: 0.095331
# 04/29/2025 05:17:22 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.18
# 04/29/2025 05:17:22 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.18
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/29/2025 05:18:53 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 05:18:53 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 05:18:53 - INFO -   Text-to-Video:
# 04/29/2025 05:18:53 - INFO -   	>>>  R@1: 36.6 - R@5: 63.6 - R@10: 72.7 - Median R: 3.0 - Mean R: 22.9
# 04/29/2025 05:18:53 - INFO -   Video-to-Text:
# 04/29/2025 05:18:53 - INFO -   	>>>  V2T$R@1: 34.4 - V2T$R@5: 62.0 - V2T$R@10: 73.6 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 05:18:53 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
# Epoch 20:  21%|██▏       | 60/281 [04:39<14:03,  3.81s/it, loss=0.0944]04/29/2025 05:23:33 - INFO -   Epoch: 20/20, Step: 61/281, Lr: , Loss: 0.094402, Time/step: 2.801536
# Epoch 20:  57%|█████▋    | 160/281 [11:51<05:02,  2.50s/it, loss=0.131]04/29/2025 05:30:45 - INFO -   Epoch: 20/20, Step: 161/281, Lr: , Loss: 0.130955, Time/step: 4.314503
# Epoch 20:  93%|█████████▎| 260/281 [19:00<01:31,  4.36s/it, loss=0.0792]04/29/2025 05:37:54 - INFO -   Epoch: 20/20, Step: 261/281, Lr: , Loss: 0.079210, Time/step: 4.294305
# Epoch 20: 100%|██████████| 281/281 [20:06<00:00,  4.29s/it, loss=0.149]
# 04/29/2025 05:39:00 - INFO -   Epoch 20/20 Finished, Train Loss: 0.101750
# 04/29/2025 05:39:00 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.19
# 04/29/2025 05:39:00 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.19
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/29/2025 05:40:31 - INFO -   sim matrix size: 1000, 1000
# 04/29/2025 05:40:31 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/29/2025 05:40:31 - INFO -   Text-to-Video:
# 04/29/2025 05:40:31 - INFO -   	>>>  R@1: 36.7 - R@5: 63.6 - R@10: 72.7 - Median R: 3.0 - Mean R: 22.9
# 04/29/2025 05:40:31 - INFO -   Video-to-Text:
# 04/29/2025 05:40:31 - INFO -   	>>>  V2T$R@1: 34.5 - V2T$R@5: 62.0 - V2T$R@10: 73.6 - V2T$Median R: 3.0 - V2T$Mean R: 19.5
# 04/29/2025 05:40:31 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 37.9000
