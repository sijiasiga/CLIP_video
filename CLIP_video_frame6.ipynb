# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_frame6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 80 (delta 32), reused 38 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 1.37 MiB | 3.40 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 6.2 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 116.7 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.01, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.01)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 90
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: Tesla T4

# %%
# Download CLIP (ViT-B/32) weight
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Out:
# --2025-04-19 03:30:58--  https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.70, 2620:1ec:bdf::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.70|:443... connected.
# HTTP request sent, awaiting response... 404 The specified blob does not exist.
# 2025-04-19 03:30:58 ERROR 404: The specified blob does not exist..

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
--do_train \
--num_thread_reader=0 \
--epochs=5 \
--batch_size=32 \
--train_csv {DATA_PATH}/MSRVTT_train.subset.csv \
--val_csv {DATA_PATH}/MSRVTT_JSFUSION_test.csv \
--data_path {DATA_PATH}/MSRVTT_data.json \
--features_path {VIDEO_PATH} \
--output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
--lr 1e-4 \
--max_words 32 \
--max_frames 8 \
--batch_size_val 8 \
--datatype msrvtt \
--expand_msrvtt_sentences \
--feature_framerate 1 \
--coef_lr 1e-3 \
--freeze_layer_num 0 \
--slice_framepos 6 \
--loose_type \
--linear_patch 2d \
--sim_header meanP \
--pretrained_clip_name ViT-B/32 \
--fp16 --fp16_opt_level O1
# Out:
# 04/19/2025 03:32:21 - INFO -   Effective parameters:
# 04/19/2025 03:32:21 - INFO -     <<< batch_size: 32
# 04/19/2025 03:32:21 - INFO -     <<< batch_size_val: 8
# 04/19/2025 03:32:21 - INFO -     <<< cache_dir:
# 04/19/2025 03:32:21 - INFO -     <<< coef_lr: 0.001
# 04/19/2025 03:32:21 - INFO -     <<< cross_model: cross-base
# 04/19/2025 03:32:21 - INFO -     <<< cross_num_hidden_layers: 4
# 04/19/2025 03:32:21 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/19/2025 03:32:21 - INFO -     <<< datatype: msrvtt
# 04/19/2025 03:32:21 - INFO -     <<< do_eval: False
# 04/19/2025 03:32:21 - INFO -     <<< do_lower_case: False
# 04/19/2025 03:32:21 - INFO -     <<< do_pretrain: False
# 04/19/2025 03:32:21 - INFO -     <<< do_train: True
# 04/19/2025 03:32:21 - INFO -     <<< epochs: 5
# 04/19/2025 03:32:21 - INFO -     <<< eval_frame_order: 0
# 04/19/2025 03:32:21 - INFO -     <<< expand_msrvtt_sentences: True
# 04/19/2025 03:32:21 - INFO -     <<< feature_framerate: 1
# 04/19/2025 03:32:21 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/19/2025 03:32:21 - INFO -     <<< fp16: True
# 04/19/2025 03:32:21 - INFO -     <<< fp16_opt_level: O1
# 04/19/2025 03:32:21 - INFO -     <<< freeze_layer_num: 0
# 04/19/2025 03:32:21 - INFO -     <<< gradient_accumulation_steps: 1
# 04/19/2025 03:32:21 - INFO -     <<< hard_negative_rate: 0.5
# 04/19/2025 03:32:21 - INFO -     <<< init_model: None
# 04/19/2025 03:32:21 - INFO -     <<< linear_patch: 2d
# 04/19/2025 03:32:21 - INFO -     <<< loose_type: True
# 04/19/2025 03:32:21 - INFO -     <<< lr: 0.0001
# 04/19/2025 03:32:21 - INFO -     <<< lr_decay: 0.9
# 04/19/2025 03:32:21 - INFO -     <<< margin: 0.1
# 04/19/2025 03:32:21 - INFO -     <<< max_frames: 8
# 04/19/2025 03:32:21 - INFO -     <<< max_words: 32
# 04/19/2025 03:32:21 - INFO -     <<< n_display: 100
# 04/19/2025 03:32:21 - INFO -     <<< n_gpu: 1
# 04/19/2025 03:32:21 - INFO -     <<< n_pair: 1
# 04/19/2025 03:32:21 - INFO -     <<< negative_weighting: 1
# 04/19/2025 03:32:21 - INFO -     <<< num_thread_reader: 0
# 04/19/2025 03:32:21 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/19/2025 03:32:21 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/19/2025 03:32:21 - INFO -     <<< rank: 0
# 04/19/2025 03:32:21 - INFO -     <<< resume_model: None
# 04/19/2025 03:32:21 - INFO -     <<< sampled_use_mil: False
# 04/19/2025 03:32:21 - INFO -     <<< seed: 42
# 04/19/2025 03:32:21 - INFO -     <<< sim_header: meanP
# 04/19/2025 03:32:21 - INFO -     <<< slice_framepos: 6
# 04/19/2025 03:32:21 - INFO -     <<< task_type: retrieval
# 04/19/2025 03:32:21 - INFO -     <<< text_num_hidden_layers: 12
# 04/19/2025 03:32:21 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/19/2025 03:32:21 - INFO -     <<< train_frame_order: 0
# 04/19/2025 03:32:21 - INFO -     <<< use_mil: False
# 04/19/2025 03:32:21 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/19/2025 03:32:21 - INFO -     <<< video_dim: 1024
# 04/19/2025 03:32:21 - INFO -     <<< visual_num_hidden_layers: 12
# 04/19/2025 03:32:21 - INFO -     <<< warmup_proportion: 0.1
# 04/19/2025 03:32:21 - INFO -     <<< world_size: 1
# 04/19/2025 03:32:21 - INFO -   device: cuda n_gpu: 1
# 100%|███████████████████████████████████████| 354M/354M [00:06<00:00, 57.8MiB/s]
# 04/19/2025 03:32:29 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/19/2025 03:32:29 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/19/2025 03:32:29 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/19/2025 03:32:29 - WARNING -   Stage-One:True, Stage-Two:False
# 04/19/2025 03:32:29 - WARNING -   Test retrieval by loose type.
# 04/19/2025 03:32:29 - WARNING -   	 embed_dim: 512
# 04/19/2025 03:32:29 - WARNING -   	 image_resolution: 224
# 04/19/2025 03:32:29 - WARNING -   	 vision_layers: 12
# 04/19/2025 03:32:29 - WARNING -   	 vision_width: 768
# 04/19/2025 03:32:29 - WARNING -   	 vision_patch_size: 32
# 04/19/2025 03:32:29 - WARNING -   	 context_length: 77
# 04/19/2025 03:32:29 - WARNING -   	 vocab_size: 49408
# 04/19/2025 03:32:29 - WARNING -   	 transformer_width: 512
# 04/19/2025 03:32:29 - WARNING -   	 transformer_heads: 8
# 04/19/2025 03:32:29 - WARNING -   	 transformer_layers: 12
# 04/19/2025 03:32:29 - WARNING -   		 linear_patch: 2d
# 04/19/2025 03:32:29 - WARNING -   	 cut_top_layer: 0
# 04/19/2025 03:32:31 - WARNING -   	 sim_header: meanP
# 04/19/2025 03:32:35 - INFO -   --------------------
# 04/19/2025 03:32:35 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/19/2025 03:32:36 - INFO -   ***** Running test *****
# 04/19/2025 03:32:36 - INFO -     Num examples = 1000
# 04/19/2025 03:32:36 - INFO -     Batch size = 8
# 04/19/2025 03:32:36 - INFO -     Num steps = 125
# 04/19/2025 03:32:36 - INFO -   ***** Running val *****
# 04/19/2025 03:32:36 - INFO -     Num examples = 1000
# 04/19/2025 03:32:37 - INFO -   ***** Running training *****
# 04/19/2025 03:32:37 - INFO -     Num examples = 1800
# 04/19/2025 03:32:37 - INFO -     Batch size = 32
# 04/19/2025 03:32:37 - INFO -     Num steps = 280
# Epoch 1: 100% 56/56 [11:58<00:00, 12.83s/it, loss=0.697]
# 04/19/2025 03:44:36 - INFO -   Epoch 1/5 Finished, Train Loss: 0.952725
# 04/19/2025 03:44:40 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/19/2025 03:44:40 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [16:31<00:00,  7.93s/it]
# 04/19/2025 04:01:18 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:01:18 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:01:18 - INFO -   Text-to-Video:
# 04/19/2025 04:01:18 - INFO -   	>>>  R@1: 34.3 - R@5: 59.0 - R@10: 70.6 - Median R: 3.0 - Mean R: 27.3
# 04/19/2025 04:01:18 - INFO -   Video-to-Text:
# 04/19/2025 04:01:18 - INFO -   	>>>  V2T$R@1: 35.2 - V2T$R@5: 61.4 - V2T$R@10: 71.9 - V2T$Median R: 3.0 - V2T$Mean R: 23.8
# 04/19/2025 04:01:18 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.3000
# Epoch 2:  77% 43/56 [07:56<02:14, 10.38s/it, loss=0.575]04/19/2025 04:09:15 - INFO -   Epoch: 2/5, Step: 44/56, Lr: , Loss: 0.574887, Time/step: 4.763793
# Epoch 2: 100% 56/56 [10:05<00:00, 10.82s/it, loss=0.501]
# 04/19/2025 04:11:24 - INFO -   Epoch 2/5 Finished, Train Loss: 0.529844
# 04/19/2025 04:11:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/19/2025 04:11:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [05:44<00:00,  2.76s/it]
# 04/19/2025 04:17:20 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:17:20 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:17:20 - INFO -   Text-to-Video:
# 04/19/2025 04:17:20 - INFO -   	>>>  R@1: 34.1 - R@5: 60.0 - R@10: 71.0 - Median R: 3.0 - Mean R: 25.0
# 04/19/2025 04:17:20 - INFO -   Video-to-Text:
# 04/19/2025 04:17:20 - INFO -   	>>>  V2T$R@1: 32.6 - V2T$R@5: 60.4 - V2T$R@10: 72.2 - V2T$Median R: 3.0 - V2T$Mean R: 20.9
# 04/19/2025 04:17:20 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.3000
# Epoch 3: 100% 56/56 [10:03<00:00, 10.78s/it, loss=0.298]
# 04/19/2025 04:27:24 - INFO -   Epoch 3/5 Finished, Train Loss: 0.399951
# 04/19/2025 04:27:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/19/2025 04:27:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [05:38<00:00,  2.71s/it]
# 04/19/2025 04:33:14 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:33:14 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:33:14 - INFO -   Text-to-Video:
# 04/19/2025 04:33:14 - INFO -   	>>>  R@1: 34.1 - R@5: 60.4 - R@10: 71.7 - Median R: 3.0 - Mean R: 25.4
# 04/19/2025 04:33:14 - INFO -   Video-to-Text:
# 04/19/2025 04:33:14 - INFO -   	>>>  V2T$R@1: 31.6 - V2T$R@5: 58.5 - V2T$R@10: 69.7 - V2T$Median R: 4.0 - V2T$Mean R: 21.6
# 04/19/2025 04:33:14 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.3000
# Epoch 4:  55% 31/56 [05:37<04:14, 10.17s/it, loss=0.378]04/19/2025 04:38:52 - INFO -   Epoch: 4/5, Step: 32/56, Lr: , Loss: 0.378350, Time/step: 3.376681
# Epoch 4: 100% 56/56 [10:02<00:00, 10.75s/it, loss=0.142]
# 04/19/2025 04:43:17 - INFO -   Epoch 4/5 Finished, Train Loss: 0.340245
# 04/19/2025 04:43:20 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/19/2025 04:43:20 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [05:42<00:00,  2.74s/it]
# 04/19/2025 04:49:09 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:49:09 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:49:09 - INFO -   Text-to-Video:
# 04/19/2025 04:49:09 - INFO -   	>>>  R@1: 34.4 - R@5: 59.6 - R@10: 71.2 - Median R: 3.0 - Mean R: 25.3
# 04/19/2025 04:49:09 - INFO -   Video-to-Text:
# 04/19/2025 04:49:09 - INFO -   	>>>  V2T$R@1: 33.0 - V2T$R@5: 58.8 - V2T$R@10: 70.5 - V2T$Median R: 3.0 - V2T$Mean R: 21.0
# 04/19/2025 04:49:09 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 34.4000
# Epoch 5: 100% 56/56 [10:08<00:00, 10.87s/it, loss=0.288]
# 04/19/2025 04:59:18 - INFO -   Epoch 5/5 Finished, Train Loss: 0.310526
# 04/19/2025 04:59:21 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/19/2025 04:59:21 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [05:39<00:00,  2.72s/it]
# 04/19/2025 05:05:07 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 05:05:07 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 05:05:07 - INFO -   Text-to-Video:
# 04/19/2025 05:05:07 - INFO -   	>>>  R@1: 34.2 - R@5: 59.8 - R@10: 71.3 - Median R: 3.0 - Mean R: 25.3
# 04/19/2025 05:05:07 - INFO -   Video-to-Text:
# 04/19/2025 05:05:07 - INFO -   	>>>  V2T$R@1: 33.2 - V2T$R@5: 58.7 - V2T$R@10: 70.6 - V2T$Median R: 3.0 - V2T$Mean R: 21.0
# 04/19/2025 05:05:07 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 34.4000
