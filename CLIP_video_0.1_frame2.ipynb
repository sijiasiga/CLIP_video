# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_0.1_frame2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 112 (delta 54), reused 49 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 1.39 MiB | 10.15 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.1 (from boto3)
#   Downloading botocore-1.38.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 3.6 MB/s eta 0:00:00
# Downloading botocore-1.38.1-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 114.5 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.4 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.1 botocore-1.38.1 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.1, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.1)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 900
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA A100-SXM4-40GB

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-24 19:28:26--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.38, 2620:1ec:bdf::38
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt.1’
#
# ViT-B-32.pt.1       100%[===================>] 337.58M  31.9MB/s    in 6.6s
#
# 2025-04-24 19:28:33 (51.4 MB/s) - ‘./modules/ViT-B-32.pt.1’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Requirement already satisfied: ffmpeg in /usr/local/lib/python3.11/dist-packages (1.4)
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
  --do_train \
  --num_thread_reader 8 \
  --epochs 5 \
  --batch_size 64 \
  --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
  --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
  --data_path  "$DATA_PATH"/MSRVTT_data.json \
  --features_path "$VIDEO_PATH" \
  --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
  --lr 1e-4 \
  --max_words 32 \
  --max_frames 8 \
  --batch_size_val 8 \
  --datatype msrvtt \
  --expand_msrvtt_sentences \
  --feature_framerate 1 \
  --coef_lr 1e-3 \
  --freeze_layer_num 6 \
  --slice_framepos 2 \
  --loose_type \
  --linear_patch 2d \
  --sim_header meanP \
  --pretrained_clip_name ViT-B/32 \
  --fp16 \
  --fp16_opt_level O1
# Out:
# 04/24/2025 19:29:02 - INFO -   Effective parameters:
# 04/24/2025 19:29:02 - INFO -     <<< batch_size: 64
# 04/24/2025 19:29:02 - INFO -     <<< batch_size_val: 8
# 04/24/2025 19:29:02 - INFO -     <<< cache_dir:
# 04/24/2025 19:29:02 - INFO -     <<< coef_lr: 0.001
# 04/24/2025 19:29:02 - INFO -     <<< cross_model: cross-base
# 04/24/2025 19:29:02 - INFO -     <<< cross_num_hidden_layers: 4
# 04/24/2025 19:29:02 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/24/2025 19:29:02 - INFO -     <<< datatype: msrvtt
# 04/24/2025 19:29:02 - INFO -     <<< do_eval: False
# 04/24/2025 19:29:02 - INFO -     <<< do_lower_case: False
# 04/24/2025 19:29:02 - INFO -     <<< do_pretrain: False
# 04/24/2025 19:29:02 - INFO -     <<< do_train: True
# 04/24/2025 19:29:02 - INFO -     <<< epochs: 5
# 04/24/2025 19:29:02 - INFO -     <<< eval_frame_order: 0
# 04/24/2025 19:29:02 - INFO -     <<< expand_msrvtt_sentences: True
# 04/24/2025 19:29:02 - INFO -     <<< feature_framerate: 1
# 04/24/2025 19:29:02 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/24/2025 19:29:02 - INFO -     <<< fp16: True
# 04/24/2025 19:29:02 - INFO -     <<< fp16_opt_level: O1
# 04/24/2025 19:29:02 - INFO -     <<< freeze_layer_num: 6
# 04/24/2025 19:29:02 - INFO -     <<< gradient_accumulation_steps: 1
# 04/24/2025 19:29:02 - INFO -     <<< hard_negative_rate: 0.5
# 04/24/2025 19:29:02 - INFO -     <<< init_model: None
# 04/24/2025 19:29:02 - INFO -     <<< linear_patch: 2d
# 04/24/2025 19:29:02 - INFO -     <<< loose_type: True
# 04/24/2025 19:29:02 - INFO -     <<< lr: 0.0001
# 04/24/2025 19:29:02 - INFO -     <<< lr_decay: 0.9
# 04/24/2025 19:29:02 - INFO -     <<< margin: 0.1
# 04/24/2025 19:29:02 - INFO -     <<< max_frames: 8
# 04/24/2025 19:29:02 - INFO -     <<< max_words: 32
# 04/24/2025 19:29:02 - INFO -     <<< n_display: 100
# 04/24/2025 19:29:02 - INFO -     <<< n_gpu: 1
# 04/24/2025 19:29:02 - INFO -     <<< n_pair: 1
# 04/24/2025 19:29:02 - INFO -     <<< negative_weighting: 1
# 04/24/2025 19:29:02 - INFO -     <<< num_thread_reader: 8
# 04/24/2025 19:29:02 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/24/2025 19:29:02 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/24/2025 19:29:02 - INFO -     <<< rank: 0
# 04/24/2025 19:29:02 - INFO -     <<< resume_model: None
# 04/24/2025 19:29:02 - INFO -     <<< sampled_use_mil: False
# 04/24/2025 19:29:02 - INFO -     <<< seed: 42
# 04/24/2025 19:29:02 - INFO -     <<< sim_header: meanP
# 04/24/2025 19:29:02 - INFO -     <<< slice_framepos: 2
# 04/24/2025 19:29:02 - INFO -     <<< task_type: retrieval
# 04/24/2025 19:29:02 - INFO -     <<< text_num_hidden_layers: 12
# 04/24/2025 19:29:02 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/24/2025 19:29:02 - INFO -     <<< train_frame_order: 0
# 04/24/2025 19:29:02 - INFO -     <<< use_mil: False
# 04/24/2025 19:29:02 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/24/2025 19:29:02 - INFO -     <<< video_dim: 1024
# 04/24/2025 19:29:02 - INFO -     <<< visual_num_hidden_layers: 12
# 04/24/2025 19:29:02 - INFO -     <<< warmup_proportion: 0.1
# 04/24/2025 19:29:02 - INFO -     <<< world_size: 1
# 04/24/2025 19:29:02 - INFO -   device: cuda n_gpu: 1
# 04/24/2025 19:29:02 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/24/2025 19:29:02 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/24/2025 19:29:02 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/24/2025 19:29:02 - WARNING -   Stage-One:True, Stage-Two:False
# 04/24/2025 19:29:02 - WARNING -   Test retrieval by loose type.
# 04/24/2025 19:29:02 - WARNING -   	 embed_dim: 512
# 04/24/2025 19:29:02 - WARNING -   	 image_resolution: 224
# 04/24/2025 19:29:02 - WARNING -   	 vision_layers: 12
# 04/24/2025 19:29:02 - WARNING -   	 vision_width: 768
# 04/24/2025 19:29:02 - WARNING -   	 vision_patch_size: 32
# 04/24/2025 19:29:02 - WARNING -   	 context_length: 77
# 04/24/2025 19:29:02 - WARNING -   	 vocab_size: 49408
# 04/24/2025 19:29:02 - WARNING -   	 transformer_width: 512
# 04/24/2025 19:29:02 - WARNING -   	 transformer_heads: 8
# 04/24/2025 19:29:02 - WARNING -   	 transformer_layers: 12
# 04/24/2025 19:29:02 - WARNING -   		 linear_patch: 2d
# 04/24/2025 19:29:02 - WARNING -   	 cut_top_layer: 0
# 04/24/2025 19:29:04 - WARNING -   	 sim_header: meanP
# 04/24/2025 19:29:08 - INFO -   --------------------
# 04/24/2025 19:29:08 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/24/2025 19:29:08 - INFO -   ***** Running test *****
# 04/24/2025 19:29:08 - INFO -     Num examples = 1000
# 04/24/2025 19:29:08 - INFO -     Batch size = 8
# 04/24/2025 19:29:08 - INFO -     Num steps = 125
# 04/24/2025 19:29:08 - INFO -   ***** Running val *****
# 04/24/2025 19:29:08 - INFO -     Num examples = 1000
# 04/24/2025 19:29:11 - INFO -   ***** Running training *****
# 04/24/2025 19:29:11 - INFO -     Num examples = 18000
# 04/24/2025 19:29:11 - INFO -     Batch size = 64
# 04/24/2025 19:29:11 - INFO -     Num steps = 1405
# Epoch 1:  35% 99/281 [07:35<15:11,  5.01s/it, loss=0.75]04/24/2025 19:36:47 - INFO -   Epoch: 1/5, Step: 100/281, Lr: , Loss: 0.750513, Time/step: 4.555755
# Epoch 1:  71% 199/281 [14:34<02:24,  1.76s/it, loss=0.575]04/24/2025 19:43:46 - INFO -   Epoch: 1/5, Step: 200/281, Lr: , Loss: 0.575062, Time/step: 4.193463
# Epoch 1: 100% 281/281 [20:09<00:00,  4.30s/it, loss=0.599]
# 04/24/2025 19:49:21 - INFO -   Epoch 1/5 Finished, Train Loss: 0.928894
# 04/24/2025 19:49:22 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/24/2025 19:49:22 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [01:15<00:00,  1.66it/s]
# 04/24/2025 19:50:44 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 19:50:44 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 19:50:44 - INFO -   Text-to-Video:
# 04/24/2025 19:50:44 - INFO -   	>>>  R@1: 37.5 - R@5: 64.6 - R@10: 75.6 - Median R: 3.0 - Mean R: 19.2
# 04/24/2025 19:50:44 - INFO -   Video-to-Text:
# 04/24/2025 19:50:44 - INFO -   	>>>  V2T$R@1: 38.8 - V2T$R@5: 64.9 - V2T$R@10: 74.9 - V2T$Median R: 3.0 - V2T$Mean R: 15.7
# 04/24/2025 19:50:44 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.5000
# Epoch 2:   6% 18/281 [01:43<28:46,  6.56s/it, loss=0.608]04/24/2025 19:52:27 - INFO -   Epoch: 2/5, Step: 19/281, Lr: , Loss: 0.608256, Time/step: 1.032230
# Epoch 2:  42% 118/281 [08:47<06:37,  2.44s/it, loss=0.651]04/24/2025 19:59:31 - INFO -   Epoch: 2/5, Step: 119/281, Lr: , Loss: 0.650955, Time/step: 4.243950
# Epoch 2:  78% 218/281 [16:05<05:44,  5.47s/it, loss=0.442]04/24/2025 20:06:50 - INFO -   Epoch: 2/5, Step: 219/281, Lr: , Loss: 0.442077, Time/step: 4.384595
# Epoch 2: 100% 281/281 [20:06<00:00,  4.29s/it, loss=0.558]
# 04/24/2025 20:10:51 - INFO -   Epoch 2/5 Finished, Train Loss: 0.507664
# 04/24/2025 20:10:52 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/24/2025 20:10:52 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [01:11<00:00,  1.76it/s]
# 04/24/2025 20:12:09 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:12:09 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:12:09 - INFO -   Text-to-Video:
# 04/24/2025 20:12:09 - INFO -   	>>>  R@1: 38.0 - R@5: 63.6 - R@10: 75.8 - Median R: 3.0 - Mean R: 19.9
# 04/24/2025 20:12:09 - INFO -   Video-to-Text:
# 04/24/2025 20:12:09 - INFO -   	>>>  V2T$R@1: 37.7 - V2T$R@5: 65.4 - V2T$R@10: 77.4 - V2T$Median R: 3.0 - V2T$Mean R: 16.3
# 04/24/2025 20:12:09 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 38.0000
# Epoch 3:  13% 37/281 [02:59<13:15,  3.26s/it, loss=0.219]04/24/2025 20:15:09 - INFO -   Epoch: 3/5, Step: 38/281, Lr: , Loss: 0.218853, Time/step: 1.801646
# Epoch 3:  49% 137/281 [10:23<08:08,  3.39s/it, loss=0.321]04/24/2025 20:22:32 - INFO -   Epoch: 3/5, Step: 138/281, Lr: , Loss: 0.320565, Time/step: 4.430552
# Epoch 3:  84% 237/281 [17:26<03:46,  5.15s/it, loss=0.277]04/24/2025 20:29:36 - INFO -   Epoch: 3/5, Step: 238/281, Lr: , Loss: 0.276494, Time/step: 4.239438
# Epoch 3: 100% 281/281 [20:06<00:00,  4.29s/it, loss=0.31]
# 04/24/2025 20:32:16 - INFO -   Epoch 3/5 Finished, Train Loss: 0.343727
# 04/24/2025 20:32:16 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/24/2025 20:32:16 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [01:12<00:00,  1.73it/s]
# 04/24/2025 20:33:35 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:33:35 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:33:35 - INFO -   Text-to-Video:
# 04/24/2025 20:33:35 - INFO -   	>>>  R@1: 36.5 - R@5: 63.9 - R@10: 74.8 - Median R: 3.0 - Mean R: 21.0
# 04/24/2025 20:33:35 - INFO -   Video-to-Text:
# 04/24/2025 20:33:35 - INFO -   	>>>  V2T$R@1: 38.0 - V2T$R@5: 64.4 - V2T$R@10: 74.9 - V2T$Median R: 3.0 - V2T$Mean R: 16.2
# 04/24/2025 20:33:35 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 38.0000
# Epoch 4:  20% 56/281 [04:43<08:28,  2.26s/it, loss=0.196]04/24/2025 20:38:19 - INFO -   Epoch: 4/5, Step: 57/281, Lr: , Loss: 0.195971, Time/step: 2.836857
# Epoch 4:  56% 156/281 [11:39<07:27,  3.58s/it, loss=0.187]04/24/2025 20:45:15 - INFO -   Epoch: 4/5, Step: 157/281, Lr: , Loss: 0.187050, Time/step: 4.162794
# Epoch 4:  91% 256/281 [18:57<00:36,  1.48s/it, loss=0.24] 04/24/2025 20:52:33 - INFO -   Epoch: 4/5, Step: 257/281, Lr: , Loss: 0.240516, Time/step: 4.379103
# Epoch 4: 100% 281/281 [20:04<00:00,  4.29s/it, loss=0.364]
# 04/24/2025 20:53:40 - INFO -   Epoch 4/5 Finished, Train Loss: 0.281835
# 04/24/2025 20:53:41 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/24/2025 20:53:41 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [01:11<00:00,  1.75it/s]
# 04/24/2025 20:54:58 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 20:54:58 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 20:54:58 - INFO -   Text-to-Video:
# 04/24/2025 20:54:58 - INFO -   	>>>  R@1: 36.9 - R@5: 64.1 - R@10: 75.4 - Median R: 3.0 - Mean R: 21.4
# 04/24/2025 20:54:58 - INFO -   Video-to-Text:
# 04/24/2025 20:54:58 - INFO -   	>>>  V2T$R@1: 36.8 - V2T$R@5: 64.0 - V2T$R@10: 73.9 - V2T$Median R: 3.0 - V2T$Mean R: 17.1
# 04/24/2025 20:54:58 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 38.0000
# Epoch 5:  27% 75/281 [05:51<21:25,  6.24s/it, loss=0.195]04/24/2025 21:00:50 - INFO -   Epoch: 5/5, Step: 76/281, Lr: , Loss: 0.195075, Time/step: 3.519394
# Epoch 5:  62% 175/281 [12:54<04:37,  2.61s/it, loss=0.244]04/24/2025 21:07:53 - INFO -   Epoch: 5/5, Step: 176/281, Lr: , Loss: 0.244105, Time/step: 4.227660
# Epoch 5:  98% 275/281 [20:00<00:32,  5.37s/it, loss=0.206]04/24/2025 21:14:59 - INFO -   Epoch: 5/5, Step: 276/281, Lr: , Loss: 0.206453, Time/step: 4.262817
# Epoch 5: 100% 281/281 [20:04<00:00,  4.28s/it, loss=0.18]
# 04/24/2025 21:15:03 - INFO -   Epoch 5/5 Finished, Train Loss: 0.257860
# 04/24/2025 21:15:04 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/24/2025 21:15:04 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [01:11<00:00,  1.74it/s]
# 04/24/2025 21:16:22 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 21:16:22 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 21:16:22 - INFO -   Text-to-Video:
# 04/24/2025 21:16:22 - INFO -   	>>>  R@1: 36.9 - R@5: 64.3 - R@10: 75.3 - Median R: 3.0 - Mean R: 21.4
# 04/24/2025 21:16:22 - INFO -   Video-to-Text:
# 04/24/2025 21:16:22 - INFO -   	>>>  V2T$R@1: 36.7 - V2T$R@5: 63.8 - V2T$R@10: 74.0 - V2T$Median R: 3.0 - V2T$Mean R: 17.2
# 04/24/2025 21:16:22 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 38.0000
