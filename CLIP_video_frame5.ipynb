# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_frame5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 80, done.
# remote: Counting objects: 100% (80/80), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 80 (delta 32), reused 38 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (80/80), 1.37 MiB | 3.14 MiB/s, done.
# Resolving deltas: 100% (32/32), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 5.2 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 90.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 6.6 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.01, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.01)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 90
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: Tesla T4

# %%
# Download CLIP (ViT-B/32) weight
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Out:
# --2025-04-19 02:48:22--  https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.70, 2620:1ec:bdf::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.70|:443... connected.
# HTTP request sent, awaiting response... 404 The specified blob does not exist.
# 2025-04-19 02:48:22 ERROR 404: The specified blob does not exist..

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
--do_train \
--num_thread_reader=0 \
--epochs=5 \
--batch_size=32 \
--train_csv {DATA_PATH}/MSRVTT_train.subset.csv \
--val_csv {DATA_PATH}/MSRVTT_JSFUSION_test.csv \
--data_path {DATA_PATH}/MSRVTT_data.json \
--features_path {VIDEO_PATH} \
--output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
--lr 1e-4 \
--max_words 32 \
--max_frames 8 \
--batch_size_val 8 \
--datatype msrvtt \
--expand_msrvtt_sentences \
--feature_framerate 1 \
--coef_lr 1e-3 \
--freeze_layer_num 0 \
--slice_framepos 5 \
--loose_type \
--linear_patch 2d \
--sim_header meanP \
--pretrained_clip_name ViT-B/32 \
--fp16 --fp16_opt_level O1
# Out:
# 04/19/2025 02:48:43 - INFO -   Effective parameters:
# 04/19/2025 02:48:43 - INFO -     <<< batch_size: 32
# 04/19/2025 02:48:43 - INFO -     <<< batch_size_val: 8
# 04/19/2025 02:48:43 - INFO -     <<< cache_dir:
# 04/19/2025 02:48:43 - INFO -     <<< coef_lr: 0.001
# 04/19/2025 02:48:43 - INFO -     <<< cross_model: cross-base
# 04/19/2025 02:48:43 - INFO -     <<< cross_num_hidden_layers: 4
# 04/19/2025 02:48:43 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/19/2025 02:48:43 - INFO -     <<< datatype: msrvtt
# 04/19/2025 02:48:43 - INFO -     <<< do_eval: False
# 04/19/2025 02:48:43 - INFO -     <<< do_lower_case: False
# 04/19/2025 02:48:43 - INFO -     <<< do_pretrain: False
# 04/19/2025 02:48:43 - INFO -     <<< do_train: True
# 04/19/2025 02:48:43 - INFO -     <<< epochs: 5
# 04/19/2025 02:48:43 - INFO -     <<< eval_frame_order: 0
# 04/19/2025 02:48:43 - INFO -     <<< expand_msrvtt_sentences: True
# 04/19/2025 02:48:43 - INFO -     <<< feature_framerate: 1
# 04/19/2025 02:48:43 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/19/2025 02:48:43 - INFO -     <<< fp16: True
# 04/19/2025 02:48:43 - INFO -     <<< fp16_opt_level: O1
# 04/19/2025 02:48:43 - INFO -     <<< freeze_layer_num: 0
# 04/19/2025 02:48:43 - INFO -     <<< gradient_accumulation_steps: 1
# 04/19/2025 02:48:43 - INFO -     <<< hard_negative_rate: 0.5
# 04/19/2025 02:48:43 - INFO -     <<< init_model: None
# 04/19/2025 02:48:43 - INFO -     <<< linear_patch: 2d
# 04/19/2025 02:48:43 - INFO -     <<< loose_type: True
# 04/19/2025 02:48:43 - INFO -     <<< lr: 0.0001
# 04/19/2025 02:48:43 - INFO -     <<< lr_decay: 0.9
# 04/19/2025 02:48:43 - INFO -     <<< margin: 0.1
# 04/19/2025 02:48:43 - INFO -     <<< max_frames: 8
# 04/19/2025 02:48:43 - INFO -     <<< max_words: 32
# 04/19/2025 02:48:43 - INFO -     <<< n_display: 100
# 04/19/2025 02:48:43 - INFO -     <<< n_gpu: 1
# 04/19/2025 02:48:43 - INFO -     <<< n_pair: 1
# 04/19/2025 02:48:43 - INFO -     <<< negative_weighting: 1
# 04/19/2025 02:48:43 - INFO -     <<< num_thread_reader: 0
# 04/19/2025 02:48:43 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/19/2025 02:48:43 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/19/2025 02:48:43 - INFO -     <<< rank: 0
# 04/19/2025 02:48:43 - INFO -     <<< resume_model: None
# 04/19/2025 02:48:43 - INFO -     <<< sampled_use_mil: False
# 04/19/2025 02:48:43 - INFO -     <<< seed: 42
# 04/19/2025 02:48:43 - INFO -     <<< sim_header: meanP
# 04/19/2025 02:48:43 - INFO -     <<< slice_framepos: 5
# 04/19/2025 02:48:43 - INFO -     <<< task_type: retrieval
# 04/19/2025 02:48:43 - INFO -     <<< text_num_hidden_layers: 12
# 04/19/2025 02:48:43 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/19/2025 02:48:43 - INFO -     <<< train_frame_order: 0
# 04/19/2025 02:48:43 - INFO -     <<< use_mil: False
# 04/19/2025 02:48:43 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/19/2025 02:48:43 - INFO -     <<< video_dim: 1024
# 04/19/2025 02:48:43 - INFO -     <<< visual_num_hidden_layers: 12
# 04/19/2025 02:48:43 - INFO -     <<< warmup_proportion: 0.1
# 04/19/2025 02:48:43 - INFO -     <<< world_size: 1
# 04/19/2025 02:48:43 - INFO -   device: cuda n_gpu: 1
# 100%|███████████████████████████████████████| 354M/354M [00:11<00:00, 31.6MiB/s]
# 04/19/2025 02:48:56 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/19/2025 02:48:56 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/19/2025 02:48:56 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/19/2025 02:48:56 - WARNING -   Stage-One:True, Stage-Two:False
# 04/19/2025 02:48:56 - WARNING -   Test retrieval by loose type.
# 04/19/2025 02:48:56 - WARNING -   	 embed_dim: 512
# 04/19/2025 02:48:56 - WARNING -   	 image_resolution: 224
# 04/19/2025 02:48:56 - WARNING -   	 vision_layers: 12
# 04/19/2025 02:48:56 - WARNING -   	 vision_width: 768
# 04/19/2025 02:48:56 - WARNING -   	 vision_patch_size: 32
# 04/19/2025 02:48:56 - WARNING -   	 context_length: 77
# 04/19/2025 02:48:56 - WARNING -   	 vocab_size: 49408
# 04/19/2025 02:48:56 - WARNING -   	 transformer_width: 512
# 04/19/2025 02:48:56 - WARNING -   	 transformer_heads: 8
# 04/19/2025 02:48:56 - WARNING -   	 transformer_layers: 12
# 04/19/2025 02:48:56 - WARNING -   		 linear_patch: 2d
# 04/19/2025 02:48:56 - WARNING -   	 cut_top_layer: 0
# 04/19/2025 02:48:58 - WARNING -   	 sim_header: meanP
# 04/19/2025 02:49:02 - INFO -   --------------------
# 04/19/2025 02:49:02 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/19/2025 02:49:03 - INFO -   ***** Running test *****
# 04/19/2025 02:49:03 - INFO -     Num examples = 1000
# 04/19/2025 02:49:03 - INFO -     Batch size = 8
# 04/19/2025 02:49:03 - INFO -     Num steps = 125
# 04/19/2025 02:49:03 - INFO -   ***** Running val *****
# 04/19/2025 02:49:03 - INFO -     Num examples = 1000
# 04/19/2025 02:49:04 - INFO -   ***** Running training *****
# 04/19/2025 02:49:04 - INFO -     Num examples = 1800
# 04/19/2025 02:49:04 - INFO -     Batch size = 32
# 04/19/2025 02:49:04 - INFO -     Num steps = 280
# Epoch 1: 100% 56/56 [11:30<00:00, 12.33s/it, loss=0.664]
# 04/19/2025 03:00:35 - INFO -   Epoch 1/5 Finished, Train Loss: 0.950133
# 04/19/2025 03:00:39 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/19/2025 03:00:39 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [16:45<00:00,  8.04s/it]
# 04/19/2025 03:17:31 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 03:17:31 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 03:17:31 - INFO -   Text-to-Video:
# 04/19/2025 03:17:31 - INFO -   	>>>  R@1: 34.8 - R@5: 58.9 - R@10: 69.1 - Median R: 3.0 - Mean R: 26.1
# 04/19/2025 03:17:31 - INFO -   Video-to-Text:
# 04/19/2025 03:17:31 - INFO -   	>>>  V2T$R@1: 34.7 - V2T$R@5: 60.0 - V2T$R@10: 71.4 - V2T$Median R: 3.0 - V2T$Mean R: 22.7
# 04/19/2025 03:17:31 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.8000
# Epoch 2:  77% 43/56 [07:37<02:11, 10.10s/it, loss=0.557]04/19/2025 03:25:09 - INFO -   Epoch: 2/5, Step: 44/56, Lr: , Loss: 0.556583, Time/step: 4.575189
# Epoch 2: 100% 56/56 [09:44<00:00, 10.43s/it, loss=0.507]
# 04/19/2025 03:27:15 - INFO -   Epoch 2/5 Finished, Train Loss: 0.525941
# 04/19/2025 03:27:23 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/19/2025 03:27:23 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [05:26<00:00,  2.62s/it]
# 04/19/2025 03:32:56 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 03:32:56 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 03:32:56 - INFO -   Text-to-Video:
# 04/19/2025 03:32:56 - INFO -   	>>>  R@1: 33.8 - R@5: 59.4 - R@10: 70.6 - Median R: 3.0 - Mean R: 23.9
# 04/19/2025 03:32:56 - INFO -   Video-to-Text:
# 04/19/2025 03:32:56 - INFO -   	>>>  V2T$R@1: 34.5 - V2T$R@5: 61.7 - V2T$R@10: 71.5 - V2T$Median R: 3.0 - V2T$Mean R: 20.5
# 04/19/2025 03:32:56 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.8000
# Epoch 3: 100% 56/56 [09:41<00:00, 10.39s/it, loss=0.288]
# 04/19/2025 03:42:38 - INFO -   Epoch 3/5 Finished, Train Loss: 0.397589
# 04/19/2025 03:42:44 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/19/2025 03:42:44 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [05:30<00:00,  2.64s/it]
# 04/19/2025 03:48:19 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 03:48:19 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 03:48:19 - INFO -   Text-to-Video:
# 04/19/2025 03:48:19 - INFO -   	>>>  R@1: 34.2 - R@5: 60.4 - R@10: 70.2 - Median R: 3.0 - Mean R: 24.4
# 04/19/2025 03:48:19 - INFO -   Video-to-Text:
# 04/19/2025 03:48:19 - INFO -   	>>>  V2T$R@1: 33.1 - V2T$R@5: 59.8 - V2T$R@10: 71.0 - V2T$Median R: 3.0 - V2T$Mean R: 21.2
# 04/19/2025 03:48:19 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.8000
# Epoch 4:  55% 31/56 [05:26<04:11, 10.07s/it, loss=0.408]04/19/2025 03:53:47 - INFO -   Epoch: 4/5, Step: 32/56, Lr: , Loss: 0.408141, Time/step: 3.269390
# Epoch 4: 100% 56/56 [09:40<00:00, 10.36s/it, loss=0.126]
# 04/19/2025 03:58:00 - INFO -   Epoch 4/5 Finished, Train Loss: 0.342449
# 04/19/2025 03:58:05 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/19/2025 03:58:05 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [05:31<00:00,  2.65s/it]
# 04/19/2025 04:03:42 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:03:42 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:03:42 - INFO -   Text-to-Video:
# 04/19/2025 04:03:42 - INFO -   	>>>  R@1: 34.0 - R@5: 60.4 - R@10: 69.9 - Median R: 3.0 - Mean R: 24.3
# 04/19/2025 04:03:42 - INFO -   Video-to-Text:
# 04/19/2025 04:03:42 - INFO -   	>>>  V2T$R@1: 33.0 - V2T$R@5: 60.5 - V2T$R@10: 71.3 - V2T$Median R: 3.0 - V2T$Mean R: 20.9
# 04/19/2025 04:03:42 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.8000
# Epoch 5: 100% 56/56 [09:41<00:00, 10.39s/it, loss=0.287]
# 04/19/2025 04:13:24 - INFO -   Epoch 5/5 Finished, Train Loss: 0.312638
# 04/19/2025 04:13:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/19/2025 04:13:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [05:29<00:00,  2.63s/it]
# 04/19/2025 04:19:03 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 04:19:03 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 04:19:03 - INFO -   Text-to-Video:
# 04/19/2025 04:19:03 - INFO -   	>>>  R@1: 34.0 - R@5: 60.4 - R@10: 70.0 - Median R: 3.0 - Mean R: 24.3
# 04/19/2025 04:19:03 - INFO -   Video-to-Text:
# 04/19/2025 04:19:03 - INFO -   	>>>  V2T$R@1: 32.9 - V2T$R@5: 60.5 - V2T$R@10: 71.4 - V2T$Median R: 3.0 - V2T$Mean R: 21.0
# 04/19/2025 04:19:03 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 34.8000
