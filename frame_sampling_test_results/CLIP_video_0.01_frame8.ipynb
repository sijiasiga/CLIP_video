# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_frame8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 96 (delta 43), reused 44 (delta 11), pack-reused 0 (from 0)
# Receiving objects: 100% (96/96), 1.38 MiB | 3.51 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.37.37-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.38.0,>=1.37.37 (from boto3)
#   Downloading botocore-1.37.37-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.12.0,>=0.11.0 (from boto3)
#   Downloading s3transfer-0.11.5-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.37.37-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 4.5 MB/s eta 0:00:00
# Downloading botocore-1.37.37-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 82.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.11.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 7.6 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.37.37 botocore-1.37.37 jmespath-1.0.1 s3transfer-0.11.5

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.01, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.01)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 90
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: Tesla T4

# %%
# Download CLIP (ViT-B/32) weight
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Out:
# --2025-04-19 17:48:45--  https://openaipublic.azureedge.net/clip/models/cc12fdd5df8b6c2c9118e754d5f1ec50b6706b3cd1a1e0dabfdfd5fcd8c38e38/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.70, 2620:1ec:bdf::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.70|:443... connected.
# HTTP request sent, awaiting response... 404 The specified blob does not exist.
# 2025-04-19 17:48:45 ERROR 404: The specified blob does not exist..

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
--do_train \
--num_thread_reader=0 \
--epochs=5 \
--batch_size=32 \
--train_csv {DATA_PATH}/MSRVTT_train.subset.csv \
--val_csv {DATA_PATH}/MSRVTT_JSFUSION_test.csv \
--data_path {DATA_PATH}/MSRVTT_data.json \
--features_path {VIDEO_PATH} \
--output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
--lr 1e-4 \
--max_words 32 \
--max_frames 8 \
--batch_size_val 8 \
--datatype msrvtt \
--expand_msrvtt_sentences \
--feature_framerate 1 \
--coef_lr 1e-3 \
--freeze_layer_num 0 \
--slice_framepos 8 \
--loose_type \
--linear_patch 2d \
--sim_header meanP \
--pretrained_clip_name ViT-B/32 \
--fp16 --fp16_opt_level O1
# Out:
# 04/19/2025 17:49:02 - INFO -   Effective parameters:
# 04/19/2025 17:49:02 - INFO -     <<< batch_size: 32
# 04/19/2025 17:49:02 - INFO -     <<< batch_size_val: 8
# 04/19/2025 17:49:02 - INFO -     <<< cache_dir:
# 04/19/2025 17:49:02 - INFO -     <<< coef_lr: 0.001
# 04/19/2025 17:49:02 - INFO -     <<< cross_model: cross-base
# 04/19/2025 17:49:02 - INFO -     <<< cross_num_hidden_layers: 4
# 04/19/2025 17:49:02 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/19/2025 17:49:02 - INFO -     <<< datatype: msrvtt
# 04/19/2025 17:49:02 - INFO -     <<< do_eval: False
# 04/19/2025 17:49:02 - INFO -     <<< do_lower_case: False
# 04/19/2025 17:49:02 - INFO -     <<< do_pretrain: False
# 04/19/2025 17:49:02 - INFO -     <<< do_train: True
# 04/19/2025 17:49:02 - INFO -     <<< epochs: 5
# 04/19/2025 17:49:02 - INFO -     <<< eval_frame_order: 0
# 04/19/2025 17:49:02 - INFO -     <<< expand_msrvtt_sentences: True
# 04/19/2025 17:49:02 - INFO -     <<< feature_framerate: 1
# 04/19/2025 17:49:02 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/19/2025 17:49:02 - INFO -     <<< fp16: True
# 04/19/2025 17:49:02 - INFO -     <<< fp16_opt_level: O1
# 04/19/2025 17:49:02 - INFO -     <<< freeze_layer_num: 0
# 04/19/2025 17:49:02 - INFO -     <<< gradient_accumulation_steps: 1
# 04/19/2025 17:49:02 - INFO -     <<< hard_negative_rate: 0.5
# 04/19/2025 17:49:02 - INFO -     <<< init_model: None
# 04/19/2025 17:49:02 - INFO -     <<< linear_patch: 2d
# 04/19/2025 17:49:02 - INFO -     <<< loose_type: True
# 04/19/2025 17:49:02 - INFO -     <<< lr: 0.0001
# 04/19/2025 17:49:02 - INFO -     <<< lr_decay: 0.9
# 04/19/2025 17:49:02 - INFO -     <<< margin: 0.1
# 04/19/2025 17:49:02 - INFO -     <<< max_frames: 8
# 04/19/2025 17:49:02 - INFO -     <<< max_words: 32
# 04/19/2025 17:49:02 - INFO -     <<< n_display: 100
# 04/19/2025 17:49:02 - INFO -     <<< n_gpu: 1
# 04/19/2025 17:49:02 - INFO -     <<< n_pair: 1
# 04/19/2025 17:49:02 - INFO -     <<< negative_weighting: 1
# 04/19/2025 17:49:02 - INFO -     <<< num_thread_reader: 0
# 04/19/2025 17:49:02 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/19/2025 17:49:02 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/19/2025 17:49:02 - INFO -     <<< rank: 0
# 04/19/2025 17:49:02 - INFO -     <<< resume_model: None
# 04/19/2025 17:49:02 - INFO -     <<< sampled_use_mil: False
# 04/19/2025 17:49:02 - INFO -     <<< seed: 42
# 04/19/2025 17:49:02 - INFO -     <<< sim_header: meanP
# 04/19/2025 17:49:02 - INFO -     <<< slice_framepos: 8
# 04/19/2025 17:49:02 - INFO -     <<< task_type: retrieval
# 04/19/2025 17:49:02 - INFO -     <<< text_num_hidden_layers: 12
# 04/19/2025 17:49:02 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/19/2025 17:49:02 - INFO -     <<< train_frame_order: 0
# 04/19/2025 17:49:02 - INFO -     <<< use_mil: False
# 04/19/2025 17:49:02 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/19/2025 17:49:02 - INFO -     <<< video_dim: 1024
# 04/19/2025 17:49:02 - INFO -     <<< visual_num_hidden_layers: 12
# 04/19/2025 17:49:02 - INFO -     <<< warmup_proportion: 0.1
# 04/19/2025 17:49:02 - INFO -     <<< world_size: 1
# 04/19/2025 17:49:02 - INFO -   device: cuda n_gpu: 1
# 100%|███████████████████████████████████████| 354M/354M [00:07<00:00, 44.9MiB/s]
# 04/19/2025 17:49:12 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/19/2025 17:49:12 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/19/2025 17:49:12 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/19/2025 17:49:12 - WARNING -   Stage-One:True, Stage-Two:False
# 04/19/2025 17:49:12 - WARNING -   Test retrieval by loose type.
# 04/19/2025 17:49:12 - WARNING -   	 embed_dim: 512
# 04/19/2025 17:49:12 - WARNING -   	 image_resolution: 224
# 04/19/2025 17:49:12 - WARNING -   	 vision_layers: 12
# 04/19/2025 17:49:12 - WARNING -   	 vision_width: 768
# 04/19/2025 17:49:12 - WARNING -   	 vision_patch_size: 32
# 04/19/2025 17:49:12 - WARNING -   	 context_length: 77
# 04/19/2025 17:49:12 - WARNING -   	 vocab_size: 49408
# 04/19/2025 17:49:12 - WARNING -   	 transformer_width: 512
# 04/19/2025 17:49:12 - WARNING -   	 transformer_heads: 8
# 04/19/2025 17:49:12 - WARNING -   	 transformer_layers: 12
# 04/19/2025 17:49:12 - WARNING -   		 linear_patch: 2d
# 04/19/2025 17:49:12 - WARNING -   	 cut_top_layer: 0
# 04/19/2025 17:49:15 - WARNING -   	 sim_header: meanP
# 04/19/2025 17:49:19 - INFO -   --------------------
# 04/19/2025 17:49:19 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/19/2025 17:49:20 - INFO -   ***** Running test *****
# 04/19/2025 17:49:20 - INFO -     Num examples = 1000
# 04/19/2025 17:49:20 - INFO -     Batch size = 8
# 04/19/2025 17:49:20 - INFO -     Num steps = 125
# 04/19/2025 17:49:20 - INFO -   ***** Running val *****
# 04/19/2025 17:49:20 - INFO -     Num examples = 1000
# 04/19/2025 17:49:21 - INFO -   ***** Running training *****
# 04/19/2025 17:49:21 - INFO -     Num examples = 1800
# 04/19/2025 17:49:21 - INFO -     Batch size = 32
# 04/19/2025 17:49:21 - INFO -     Num steps = 280
# Epoch 1: 100% 56/56 [11:14<00:00, 12.05s/it, loss=0.597]
# 04/19/2025 18:00:36 - INFO -   Epoch 1/5 Finished, Train Loss: 0.958433
# 04/19/2025 18:00:43 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/19/2025 18:00:43 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [15:03<00:00,  7.23s/it]
# 04/19/2025 18:15:52 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 18:15:52 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 18:15:52 - INFO -   Text-to-Video:
# 04/19/2025 18:15:52 - INFO -   	>>>  R@1: 33.7 - R@5: 58.9 - R@10: 70.5 - Median R: 3.0 - Mean R: 25.4
# 04/19/2025 18:15:52 - INFO -   Video-to-Text:
# 04/19/2025 18:15:52 - INFO -   	>>>  V2T$R@1: 35.2 - V2T$R@5: 61.0 - V2T$R@10: 71.6 - V2T$Median R: 3.0 - V2T$Mean R: 22.4
# 04/19/2025 18:15:52 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 33.7000
# Epoch 2:  77% 43/56 [07:26<02:04,  9.60s/it, loss=0.551]04/19/2025 18:23:19 - INFO -   Epoch: 2/5, Step: 44/56, Lr: , Loss: 0.551095, Time/step: 4.466770
# Epoch 2: 100% 56/56 [09:30<00:00, 10.18s/it, loss=0.522]
# 04/19/2025 18:25:23 - INFO -   Epoch 2/5 Finished, Train Loss: 0.534066
# 04/19/2025 18:25:27 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/19/2025 18:25:27 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [05:20<00:00,  2.57s/it]
# 04/19/2025 18:30:54 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 18:30:54 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 18:30:54 - INFO -   Text-to-Video:
# 04/19/2025 18:30:54 - INFO -   	>>>  R@1: 36.2 - R@5: 58.7 - R@10: 71.4 - Median R: 3.0 - Mean R: 23.1
# 04/19/2025 18:30:54 - INFO -   Video-to-Text:
# 04/19/2025 18:30:54 - INFO -   	>>>  V2T$R@1: 33.9 - V2T$R@5: 60.7 - V2T$R@10: 72.3 - V2T$Median R: 3.0 - V2T$Mean R: 20.9
# 04/19/2025 18:30:55 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1, the R1 is: 36.2000
# Epoch 3: 100% 56/56 [09:29<00:00, 10.17s/it, loss=0.284]
# 04/19/2025 18:40:24 - INFO -   Epoch 3/5 Finished, Train Loss: 0.401297
# 04/19/2025 18:40:27 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/19/2025 18:40:27 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [05:21<00:00,  2.57s/it]
# 04/19/2025 18:45:54 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 18:45:54 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 18:45:54 - INFO -   Text-to-Video:
# 04/19/2025 18:45:54 - INFO -   	>>>  R@1: 36.2 - R@5: 59.6 - R@10: 69.7 - Median R: 3.0 - Mean R: 24.0
# 04/19/2025 18:45:54 - INFO -   Video-to-Text:
# 04/19/2025 18:45:54 - INFO -   	>>>  V2T$R@1: 33.3 - V2T$R@5: 58.9 - V2T$R@10: 71.3 - V2T$Median R: 3.0 - V2T$Mean R: 21.6
# 04/19/2025 18:45:54 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 36.2000
# Epoch 4:  55% 31/56 [05:19<04:03,  9.75s/it, loss=0.431]04/19/2025 18:51:14 - INFO -   Epoch: 4/5, Step: 32/56, Lr: , Loss: 0.431435, Time/step: 3.194388
# Epoch 4: 100% 56/56 [09:29<00:00, 10.17s/it, loss=0.128]
# 04/19/2025 18:55:24 - INFO -   Epoch 4/5 Finished, Train Loss: 0.346350
# 04/19/2025 18:55:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/19/2025 18:55:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [05:22<00:00,  2.58s/it]
# 04/19/2025 19:00:56 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 19:00:56 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 19:00:56 - INFO -   Text-to-Video:
# 04/19/2025 19:00:56 - INFO -   	>>>  R@1: 36.0 - R@5: 60.2 - R@10: 70.3 - Median R: 3.0 - Mean R: 23.8
# 04/19/2025 19:00:56 - INFO -   Video-to-Text:
# 04/19/2025 19:00:56 - INFO -   	>>>  V2T$R@1: 34.2 - V2T$R@5: 59.1 - V2T$R@10: 72.1 - V2T$Median R: 3.0 - V2T$Mean R: 21.1
# 04/19/2025 19:00:56 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 36.2000
# Epoch 5: 100% 56/56 [09:32<00:00, 10.22s/it, loss=0.301]
# 04/19/2025 19:10:28 - INFO -   Epoch 5/5 Finished, Train Loss: 0.314882
# 04/19/2025 19:10:32 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/19/2025 19:10:32 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [05:27<00:00,  2.62s/it]
# 04/19/2025 19:16:06 - INFO -   sim matrix size: 1000, 1000
# 04/19/2025 19:16:06 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/19/2025 19:16:06 - INFO -   Text-to-Video:
# 04/19/2025 19:16:06 - INFO -   	>>>  R@1: 35.9 - R@5: 60.1 - R@10: 70.4 - Median R: 3.0 - Mean R: 23.8
# 04/19/2025 19:16:06 - INFO -   Video-to-Text:
# 04/19/2025 19:16:06 - INFO -   	>>>  V2T$R@1: 34.1 - V2T$R@5: 59.4 - V2T$R@10: 72.0 - V2T$Median R: 3.0 - V2T$Mean R: 21.1
# 04/19/2025 19:16:06 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 36.2000
