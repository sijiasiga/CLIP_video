# %%
# !git clone https://github.com/Hang-Ruan/CLIP_video.git
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 79, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 79 (delta 31), reused 40 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (79/79), 1.36 MiB | 24.04 MiB/s, done.
# Resolving deltas: 100% (31/31), done.

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.1 (from boto3)
#   Downloading botocore-1.38.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 11.3 MB/s eta 0:00:00
# Downloading botocore-1.38.1-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 121.5 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.6 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.1 botocore-1.38.1 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/IDL/IDL Project/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.1, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.1)
print("Size of subset：", len(subset_df))
display(subset_df.head())

# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 900
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139
# Subset CSV saved to: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA L4

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-24 15:34:35--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.253.70, 2620:1ec:29:1::70
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.253.70|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt’
#
# ViT-B-32.pt         100%[===================>] 337.58M  92.6MB/s    in 3.6s
#
# 2025-04-24 15:34:39 (92.7 MB/s) - ‘./modules/ViT-B-32.pt’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# Already up to date.

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=9498c042b24cf5969fdb159dc7167087b97508c177a9014a9f73de86d77d9814
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
# %%bash
# export DATA_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data"
# export VIDEO_PATH="/content/drive/MyDrive/IDL/IDL Project/Data/video"
#
# python /content/CLIP_video/main_task_retrieval.py \
#   --do_train \
#   --num_thread_reader 8 \
#   --epochs 20 \
#   --batch_size 64 \
#   --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
#   --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
#   --data_path  "$DATA_PATH"/MSRVTT_data.json \
#   --features_path "$VIDEO_PATH" \
#   --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
#   --lr 1e-4 \
#   --max_words 32 \
#   --max_frames 8 \
#   --batch_size_val 8 \
#   --datatype msrvtt \
#   --expand_msrvtt_sentences \
#   --feature_framerate 1 \
#   --coef_lr 1e-3 \
#   --freeze_layer_num 6 \
#   --slice_framepos 2 \
#   --loose_type \
#   --linear_patch 2d \
#   --sim_header seqLSTM \
#   --pretrained_clip_name ViT-B/32 \
#   --fp16 \
#   --fp16_opt_level O1
# Out:
# 124/125
# 04/24/2025 17:30:52 - INFO -   Effective parameters:
# 04/24/2025 17:30:52 - INFO -     <<< batch_size: 64
# 04/24/2025 17:30:52 - INFO -     <<< batch_size_val: 8
# 04/24/2025 17:30:52 - INFO -     <<< cache_dir:
# 04/24/2025 17:30:52 - INFO -     <<< coef_lr: 0.001
# 04/24/2025 17:30:52 - INFO -     <<< cross_model: cross-base
# 04/24/2025 17:30:52 - INFO -     <<< cross_num_hidden_layers: 4
# 04/24/2025 17:30:52 - INFO -     <<< data_path: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_data.json
# 04/24/2025 17:30:52 - INFO -     <<< datatype: msrvtt
# 04/24/2025 17:30:52 - INFO -     <<< do_eval: False
# 04/24/2025 17:30:52 - INFO -     <<< do_lower_case: False
# 04/24/2025 17:30:52 - INFO -     <<< do_pretrain: False
# 04/24/2025 17:30:52 - INFO -     <<< do_train: True
# 04/24/2025 17:30:52 - INFO -     <<< epochs: 5
# 04/24/2025 17:30:52 - INFO -     <<< eval_frame_order: 0
# 04/24/2025 17:30:52 - INFO -     <<< expand_msrvtt_sentences: True
# 04/24/2025 17:30:52 - INFO -     <<< feature_framerate: 1
# 04/24/2025 17:30:52 - INFO -     <<< features_path: /content/drive/MyDrive/IDL/IDL Project/Data/video
# 04/24/2025 17:30:52 - INFO -     <<< fp16: True
# 04/24/2025 17:30:52 - INFO -     <<< fp16_opt_level: O1
# 04/24/2025 17:30:52 - INFO -     <<< freeze_layer_num: 6
# 04/24/2025 17:30:52 - INFO -     <<< gradient_accumulation_steps: 1
# 04/24/2025 17:30:52 - INFO -     <<< hard_negative_rate: 0.5
# 04/24/2025 17:30:52 - INFO -     <<< init_model: None
# 04/24/2025 17:30:52 - INFO -     <<< linear_patch: 2d
# 04/24/2025 17:30:52 - INFO -     <<< loose_type: True
# 04/24/2025 17:30:52 - INFO -     <<< lr: 0.0001
# 04/24/2025 17:30:52 - INFO -     <<< lr_decay: 0.9
# 04/24/2025 17:30:52 - INFO -     <<< margin: 0.1
# 04/24/2025 17:30:52 - INFO -     <<< max_frames: 8
# 04/24/2025 17:30:52 - INFO -     <<< max_words: 32
# 04/24/2025 17:30:52 - INFO -     <<< n_display: 100
# 04/24/2025 17:30:52 - INFO -     <<< n_gpu: 1
# 04/24/2025 17:30:52 - INFO -     <<< n_pair: 1
# 04/24/2025 17:30:52 - INFO -     <<< negative_weighting: 1
# 04/24/2025 17:30:52 - INFO -     <<< num_thread_reader: 8
# 04/24/2025 17:30:52 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/24/2025 17:30:52 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/24/2025 17:30:52 - INFO -     <<< rank: 0
# 04/24/2025 17:30:52 - INFO -     <<< resume_model: None
# 04/24/2025 17:30:52 - INFO -     <<< sampled_use_mil: False
# 04/24/2025 17:30:52 - INFO -     <<< seed: 42
# 04/24/2025 17:30:52 - INFO -     <<< sim_header: seqLSTM
# 04/24/2025 17:30:52 - INFO -     <<< slice_framepos: 2
# 04/24/2025 17:30:52 - INFO -     <<< task_type: retrieval
# 04/24/2025 17:30:52 - INFO -     <<< text_num_hidden_layers: 12
# 04/24/2025 17:30:52 - INFO -     <<< train_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/24/2025 17:30:52 - INFO -     <<< train_frame_order: 0
# 04/24/2025 17:30:52 - INFO -     <<< use_mil: False
# 04/24/2025 17:30:52 - INFO -     <<< val_csv: /content/drive/MyDrive/IDL/IDL Project/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/24/2025 17:30:52 - INFO -     <<< video_dim: 1024
# 04/24/2025 17:30:52 - INFO -     <<< visual_num_hidden_layers: 12
# 04/24/2025 17:30:52 - INFO -     <<< warmup_proportion: 0.1
# 04/24/2025 17:30:52 - INFO -     <<< world_size: 1
# 04/24/2025 17:30:52 - INFO -   device: cuda n_gpu: 1
# 04/24/2025 17:30:54 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/24/2025 17:30:54 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/24/2025 17:30:54 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/24/2025 17:30:54 - WARNING -   Stage-One:True, Stage-Two:False
# 04/24/2025 17:30:54 - WARNING -   Test retrieval by loose type.
# 04/24/2025 17:30:54 - WARNING -   	 embed_dim: 512
# 04/24/2025 17:30:54 - WARNING -   	 image_resolution: 224
# 04/24/2025 17:30:54 - WARNING -   	 vision_layers: 12
# 04/24/2025 17:30:54 - WARNING -   	 vision_width: 768
# 04/24/2025 17:30:54 - WARNING -   	 vision_patch_size: 32
# 04/24/2025 17:30:54 - WARNING -   	 context_length: 77
# 04/24/2025 17:30:54 - WARNING -   	 vocab_size: 49408
# 04/24/2025 17:30:54 - WARNING -   	 transformer_width: 512
# 04/24/2025 17:30:54 - WARNING -   	 transformer_heads: 8
# 04/24/2025 17:30:54 - WARNING -   	 transformer_layers: 12
# 04/24/2025 17:30:54 - WARNING -   		 linear_patch: 2d
# 04/24/2025 17:30:54 - WARNING -   	 cut_top_layer: 0
# 04/24/2025 17:30:56 - WARNING -   	 sim_header: seqLSTM
# 04/24/2025 17:31:00 - INFO -   --------------------
# 04/24/2025 17:31:00 - INFO -   Weights of CLIP4Clip not initialized from pretrained model:
#    lstm_visual.weight_ih_l0
#    lstm_visual.weight_hh_l0
#    lstm_visual.bias_ih_l0
#    lstm_visual.bias_hh_l0
# 04/24/2025 17:31:00 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/24/2025 17:31:00 - INFO -   ***** Running test *****
# 04/24/2025 17:31:00 - INFO -     Num examples = 1000
# 04/24/2025 17:31:00 - INFO -     Batch size = 8
# 04/24/2025 17:31:00 - INFO -     Num steps = 125
# 04/24/2025 17:31:00 - INFO -   ***** Running val *****
# 04/24/2025 17:31:00 - INFO -     Num examples = 1000
# 04/24/2025 17:31:03 - INFO -   ***** Running training *****
# 04/24/2025 17:31:03 - INFO -     Num examples = 18000
# 04/24/2025 17:31:03 - INFO -     Batch size = 64
# 04/24/2025 17:31:03 - INFO -     Num steps = 1405
# Epoch 1:  35%|███▌      | 99/281 [07:38<16:04,  5.30s/it, loss=0.881]04/24/2025 17:38:42 - INFO -   Epoch: 1/5, Step: 100/281, Lr: , Loss: 0.880591, Time/step: 4.586309
# Epoch 1:  71%|███████   | 199/281 [14:40<03:12,  2.35s/it, loss=0.635]04/24/2025 17:45:44 - INFO -   Epoch: 1/5, Step: 200/281, Lr: , Loss: 0.634741, Time/step: 4.216410
# Epoch 1: 100%|██████████| 281/281 [20:15<00:00,  4.33s/it, loss=0.515]
# 04/24/2025 17:51:19 - INFO -   Epoch 1/5 Finished, Train Loss: 0.942661
# 04/24/2025 17:51:21 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/24/2025 17:51:21 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.75it/s]
# 04/24/2025 17:52:51 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 17:52:51 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 17:52:51 - INFO -   Text-to-Video:
# 04/24/2025 17:52:51 - INFO -   	>>>  R@1: 37.5 - R@5: 63.2 - R@10: 75.9 - Median R: 3.0 - Mean R: 20.2
# 04/24/2025 17:52:51 - INFO -   Video-to-Text:
# 04/24/2025 17:52:51 - INFO -   	>>>  V2T$R@1: 36.9 - V2T$R@5: 63.5 - V2T$R@10: 75.9 - V2T$Median R: 3.0 - V2T$Mean R: 17.0
# 04/24/2025 17:52:51 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.5000
# Epoch 2:   6%|▋         | 18/281 [01:50<34:02,  7.76s/it, loss=0.409]04/24/2025 17:54:42 - INFO -   Epoch: 2/5, Step: 19/281, Lr: , Loss: 0.409538, Time/step: 1.105177
# Epoch 2:  42%|████▏     | 118/281 [09:01<08:31,  3.14s/it, loss=0.63] 04/24/2025 18:01:53 - INFO -   Epoch: 2/5, Step: 119/281, Lr: , Loss: 0.629625, Time/step: 4.308410
# Epoch 2:  78%|███████▊  | 218/281 [16:15<07:29,  7.14s/it, loss=0.459]04/24/2025 18:09:07 - INFO -   Epoch: 2/5, Step: 219/281, Lr: , Loss: 0.459105, Time/step: 4.341993
# Epoch 2: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.482]
# 04/24/2025 18:13:06 - INFO -   Epoch 2/5 Finished, Train Loss: 0.503427
# 04/24/2025 18:13:07 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/24/2025 18:13:07 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.77it/s]
# 04/24/2025 18:14:37 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 18:14:37 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 18:14:37 - INFO -   Text-to-Video:
# 04/24/2025 18:14:37 - INFO -   	>>>  R@1: 37.2 - R@5: 63.6 - R@10: 74.2 - Median R: 3.0 - Mean R: 20.8
# 04/24/2025 18:14:37 - INFO -   Video-to-Text:
# 04/24/2025 18:14:37 - INFO -   	>>>  V2T$R@1: 37.2 - V2T$R@5: 64.5 - V2T$R@10: 74.8 - V2T$Median R: 3.0 - V2T$Mean R: 17.3
# 04/24/2025 18:14:37 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.5000
# Epoch 3:  13%|█▎        | 37/281 [03:02<15:18,  3.77s/it, loss=0.315]04/24/2025 18:17:40 - INFO -   Epoch: 3/5, Step: 38/281, Lr: , Loss: 0.314828, Time/step: 1.828980
# Epoch 3:  49%|████▉     | 137/281 [10:24<12:28,  5.20s/it, loss=0.634]04/24/2025 18:25:01 - INFO -   Epoch: 3/5, Step: 138/281, Lr: , Loss: 0.634403, Time/step: 4.415596
# Epoch 3:  84%|████████▍ | 237/281 [17:26<02:55,  3.99s/it, loss=0.345]04/24/2025 18:32:04 - INFO -   Epoch: 3/5, Step: 238/281, Lr: , Loss: 0.345146, Time/step: 4.227199
# Epoch 3: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.4]
# 04/24/2025 18:34:51 - INFO -   Epoch 3/5 Finished, Train Loss: 0.344808
# 04/24/2025 18:34:52 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/24/2025 18:34:52 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100%|██████████| 125/125 [01:12<00:00,  1.73it/s]
# 04/24/2025 18:36:24 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 18:36:24 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 18:36:24 - INFO -   Text-to-Video:
# 04/24/2025 18:36:24 - INFO -   	>>>  R@1: 38.3 - R@5: 63.3 - R@10: 74.4 - Median R: 3.0 - Mean R: 21.6
# 04/24/2025 18:36:24 - INFO -   Video-to-Text:
# 04/24/2025 18:36:24 - INFO -   	>>>  V2T$R@1: 34.8 - V2T$R@5: 62.8 - V2T$R@10: 74.5 - V2T$Median R: 3.0 - V2T$Mean R: 17.7
# 04/24/2025 18:36:24 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2, the R1 is: 38.3000
# Epoch 4:  20%|█▉        | 56/281 [04:32<08:18,  2.22s/it, loss=0.216]04/24/2025 18:40:56 - INFO -   Epoch: 4/5, Step: 57/281, Lr: , Loss: 0.215917, Time/step: 2.723326
# Epoch 4:  56%|█████▌    | 156/281 [11:36<07:37,  3.66s/it, loss=0.299]04/24/2025 18:48:01 - INFO -   Epoch: 4/5, Step: 157/281, Lr: , Loss: 0.299265, Time/step: 4.247118
# Epoch 4:  91%|█████████ | 256/281 [19:05<00:43,  1.74s/it, loss=0.268]04/24/2025 18:55:29 - INFO -   Epoch: 4/5, Step: 257/281, Lr: , Loss: 0.268265, Time/step: 4.486782
# Epoch 4: 100%|██████████| 281/281 [20:13<00:00,  4.32s/it, loss=0.422]
# 04/24/2025 18:56:38 - INFO -   Epoch 4/5 Finished, Train Loss: 0.260291
# 04/24/2025 18:56:39 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/24/2025 18:56:39 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100%|██████████| 125/125 [01:11<00:00,  1.74it/s]
# 04/24/2025 18:58:10 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 18:58:10 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 18:58:10 - INFO -   Text-to-Video:
# 04/24/2025 18:58:10 - INFO -   	>>>  R@1: 38.5 - R@5: 63.6 - R@10: 74.1 - Median R: 3.0 - Mean R: 21.9
# 04/24/2025 18:58:10 - INFO -   Video-to-Text:
# 04/24/2025 18:58:10 - INFO -   	>>>  V2T$R@1: 36.6 - V2T$R@5: 63.2 - V2T$R@10: 74.5 - V2T$Median R: 3.0 - V2T$Mean R: 18.0
# 04/24/2025 18:58:10 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3, the R1 is: 38.5000
# Epoch 5:  27%|██▋       | 75/281 [05:42<14:49,  4.32s/it, loss=0.166]04/24/2025 19:03:53 - INFO -   Epoch: 5/5, Step: 76/281, Lr: , Loss: 0.165587, Time/step: 3.426450
# Epoch 5:  62%|██████▏   | 175/281 [12:41<04:17,  2.43s/it, loss=0.134]04/24/2025 19:10:52 - INFO -   Epoch: 5/5, Step: 176/281, Lr: , Loss: 0.134059, Time/step: 4.192583
# Epoch 5:  98%|█████████▊| 275/281 [20:00<00:21,  3.56s/it, loss=0.175]04/24/2025 19:18:11 - INFO -   Epoch: 5/5, Step: 276/281, Lr: , Loss: 0.174629, Time/step: 4.386313
# Epoch 5: 100%|██████████| 281/281 [20:08<00:00,  4.30s/it, loss=0.137]
# 04/24/2025 19:18:19 - INFO -   Epoch 5/5 Finished, Train Loss: 0.242204
# 04/24/2025 19:18:20 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/24/2025 19:18:20 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100%|██████████| 125/125 [01:10<00:00,  1.78it/s]
# 04/24/2025 19:19:50 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 19:19:50 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 19:19:50 - INFO -   Text-to-Video:
# 04/24/2025 19:19:50 - INFO -   	>>>  R@1: 38.6 - R@5: 63.5 - R@10: 73.8 - Median R: 3.0 - Mean R: 21.9
# 04/24/2025 19:19:50 - INFO -   Video-to-Text:
# 04/24/2025 19:19:50 - INFO -   	>>>  V2T$R@1: 36.6 - V2T$R@5: 63.2 - V2T$R@10: 74.6 - V2T$Median R: 3.0 - V2T$Mean R: 18.0
# 04/24/2025 19:19:50 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4, the R1 is: 38.6000
