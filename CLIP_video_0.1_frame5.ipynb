# %% [markdown]
# <a href="https://colab.research.google.com/github/maxy808/CLIP_video/blob/frame-selection-xiaoyang/CLIP_video_0.1_frame5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b frame-selection-xiaoyang https://github.com/maxy808/CLIP_video.git
# %cd CLIP_video
# Out:
# Cloning into 'CLIP_video'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (92/92), done.
# remote: Total 112 (delta 54), reused 49 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 1.39 MiB | 21.87 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
# /content/CLIP_video

# %%
# From CLIP
# !conda install --yes -c pytorch pytorch=1.7.1 torchvision cudatoolkit=11.0
# !pip install ftfy regex tqdm
# !pip install opencv-python boto3 requests pandas
# Out:
# /bin/bash: line 1: conda: command not found
# Collecting ftfy
#   Downloading ftfy-6.3.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (4.67.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy) (0.2.13)
# Downloading ftfy-6.3.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: ftfy
# Successfully installed ftfy-6.3.1
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Collecting boto3
#   Downloading boto3-1.38.2-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Collecting botocore<1.39.0,>=1.38.2 (from boto3)
#   Downloading botocore-1.38.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.13.0,>=0.12.0 (from boto3)
#   Downloading s3transfer-0.12.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading boto3-1.38.2-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.9/139.9 kB 10.3 MB/s eta 0:00:00
# Downloading botocore-1.38.2-py3-none-any.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 119.0 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.12.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.8/84.8 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.38.2 botocore-1.38.2 jmespath-1.0.1 s3transfer-0.12.0

# %%
# Connet to google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# # Comment if the file exits
# !wget -O /content/drive/MyDrive/Data/msrvtt_data.zip https://github.com/ArrowLuo/CLIP4Clip/releases/download/v0.0/msrvtt_data.zip
# !unzip /content/drive/MyDrive/Data/msrvtt_data.zip -d /content/drive/MyDrive/Data/

# %%
DATA_PATH = "/content/drive/MyDrive/Data/msrvtt_data"  # Directory of MSRVTT data
VIDEO_PATH = "/content/drive/MyDrive/Data/video"    # Directory of MSRVTT raw video

# %%
import pandas as pd

# Load training dataset
train_path = f"{DATA_PATH}/MSRVTT_train.9k.csv"
df = pd.read_csv(train_path)

print("Size: ", len(df))
print("Column names", df.columns.tolist())
display(df.head())

# Choose a subset
def sample_subset(df, frac=0.1, random_state=42):
    return df.sample(frac=frac, random_state=random_state).reset_index(drop=True)

# Set fraction to 0.01
subset_df = sample_subset(df, frac=0.1)
print("Size of subset：", len(subset_df))
display(subset_df.head())
# Out:
# Size:  9000
# Column names ['video_id']
#   video_id
# 0   video0
# 1   video1
# 2   video2
# 3   video3
# 4   video4
# Size of subset： 900
#     video_id
# 0  video8405
# 1  video1162
# 2   video582
# 3  video4081
# 4  video9139

# %%
# Save the subset
subset_path = f"{DATA_PATH}/MSRVTT_train.subset.csv"
subset_df.to_csv(subset_path, index=False)

print("Subset CSV saved to:", subset_path)
# Out:
# Subset CSV saved to: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv

# %%
import torch
print("Current device:", torch.cuda.get_device_name() if torch.cuda.is_available() else "CPU only")
# Out:
# Current device: NVIDIA A100-SXM4-40GB

# %%
# !wget -P ./modules https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Out:
# --2025-04-24 21:28:29--  https://openaipublic.azureedge.net/clip/models/40d365715913c9da98579312b702a82c18be219cc2a73407c4526f58eba950af/ViT-B-32.pt
# Resolving openaipublic.azureedge.net (openaipublic.azureedge.net)... 13.107.246.59, 2620:1ec:bdf::59
# Connecting to openaipublic.azureedge.net (openaipublic.azureedge.net)|13.107.246.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 353976522 (338M) [application/octet-stream]
# Saving to: ‘./modules/ViT-B-32.pt’
#
# ViT-B-32.pt         100%[===================>] 337.58M  72.5MB/s    in 4.9s
#
# 2025-04-24 21:28:34 (68.3 MB/s) - ‘./modules/ViT-B-32.pt’ saved [353976522/353976522]

# %%
torch.cuda.empty_cache()

# %%
# Updata changes to files. Comment if the files are not changed
# !cd CLIP_video && git pull
# Out:
# /bin/bash: line 1: cd: CLIP_video: No such file or directory

# %%
# !pip install ffmpeg
# !python /content/CLIP_video/preprocess/compress_video.py --input_root "/content/drive/MyDrive/IDL/IDL Project/Data/video" --output_root "/content/drive/MyDrive/IDL/IDL Project/Data/compressed_video"
# Out:
# Collecting ffmpeg
#   Downloading ffmpeg-1.4.tar.gz (5.1 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ffmpeg
#   Building wheel for ffmpeg (setup.py) ... done
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-py3-none-any.whl size=6083 sha256=b215bb9bd9110b32e729c3cb6f6c488ed55bda2092b54c1a32b25327e51a4015
#   Stored in directory: /root/.cache/pip/wheels/56/30/c5/576bdd729f3bc062d62a551be7fefd6ed2f761901568171e4e
# Successfully built ffmpeg
# Installing collected packages: ffmpeg
# Successfully installed ffmpeg-1.4
# Total video need to process: 0
# Begin with 12-core logical processor.
# Compress finished, wait for checking files...

# %%
import os
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# !python /content/CLIP_video/main_task_retrieval.py \
  --do_train \
  --num_thread_reader 8 \
  --epochs 5 \
  --batch_size 64 \
  --train_csv  "$DATA_PATH"/MSRVTT_train.subset.csv \
  --val_csv    "$DATA_PATH"/MSRVTT_JSFUSION_test.csv \
  --data_path  "$DATA_PATH"/MSRVTT_data.json \
  --features_path "$VIDEO_PATH" \
  --output_dir /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType \
  --lr 1e-4 \
  --max_words 32 \
  --max_frames 8 \
  --batch_size_val 8 \
  --datatype msrvtt \
  --expand_msrvtt_sentences \
  --feature_framerate 1 \
  --coef_lr 1e-3 \
  --freeze_layer_num 6 \
  --slice_framepos 5 \
  --loose_type \
  --linear_patch 2d \
  --sim_header meanP \
  --pretrained_clip_name ViT-B/32 \
  --fp16 \
  --fp16_opt_level O1
# Out:
# 04/24/2025 21:29:11 - INFO -   Effective parameters:
# 04/24/2025 21:29:11 - INFO -     <<< batch_size: 64
# 04/24/2025 21:29:11 - INFO -     <<< batch_size_val: 8
# 04/24/2025 21:29:11 - INFO -     <<< cache_dir:
# 04/24/2025 21:29:11 - INFO -     <<< coef_lr: 0.001
# 04/24/2025 21:29:11 - INFO -     <<< cross_model: cross-base
# 04/24/2025 21:29:11 - INFO -     <<< cross_num_hidden_layers: 4
# 04/24/2025 21:29:11 - INFO -     <<< data_path: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_data.json
# 04/24/2025 21:29:11 - INFO -     <<< datatype: msrvtt
# 04/24/2025 21:29:11 - INFO -     <<< do_eval: False
# 04/24/2025 21:29:11 - INFO -     <<< do_lower_case: False
# 04/24/2025 21:29:11 - INFO -     <<< do_pretrain: False
# 04/24/2025 21:29:11 - INFO -     <<< do_train: True
# 04/24/2025 21:29:11 - INFO -     <<< epochs: 5
# 04/24/2025 21:29:11 - INFO -     <<< eval_frame_order: 0
# 04/24/2025 21:29:11 - INFO -     <<< expand_msrvtt_sentences: True
# 04/24/2025 21:29:11 - INFO -     <<< feature_framerate: 1
# 04/24/2025 21:29:11 - INFO -     <<< features_path: /content/drive/MyDrive/Data/video
# 04/24/2025 21:29:11 - INFO -     <<< fp16: True
# 04/24/2025 21:29:11 - INFO -     <<< fp16_opt_level: O1
# 04/24/2025 21:29:11 - INFO -     <<< freeze_layer_num: 6
# 04/24/2025 21:29:11 - INFO -     <<< gradient_accumulation_steps: 1
# 04/24/2025 21:29:11 - INFO -     <<< hard_negative_rate: 0.5
# 04/24/2025 21:29:11 - INFO -     <<< init_model: None
# 04/24/2025 21:29:11 - INFO -     <<< linear_patch: 2d
# 04/24/2025 21:29:11 - INFO -     <<< loose_type: True
# 04/24/2025 21:29:11 - INFO -     <<< lr: 0.0001
# 04/24/2025 21:29:11 - INFO -     <<< lr_decay: 0.9
# 04/24/2025 21:29:11 - INFO -     <<< margin: 0.1
# 04/24/2025 21:29:11 - INFO -     <<< max_frames: 8
# 04/24/2025 21:29:11 - INFO -     <<< max_words: 32
# 04/24/2025 21:29:11 - INFO -     <<< n_display: 100
# 04/24/2025 21:29:11 - INFO -     <<< n_gpu: 1
# 04/24/2025 21:29:11 - INFO -     <<< n_pair: 1
# 04/24/2025 21:29:11 - INFO -     <<< negative_weighting: 1
# 04/24/2025 21:29:11 - INFO -     <<< num_thread_reader: 8
# 04/24/2025 21:29:11 - INFO -     <<< output_dir: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType
# 04/24/2025 21:29:11 - INFO -     <<< pretrained_clip_name: ViT-B/32
# 04/24/2025 21:29:11 - INFO -     <<< rank: 0
# 04/24/2025 21:29:11 - INFO -     <<< resume_model: None
# 04/24/2025 21:29:11 - INFO -     <<< sampled_use_mil: False
# 04/24/2025 21:29:11 - INFO -     <<< seed: 42
# 04/24/2025 21:29:11 - INFO -     <<< sim_header: meanP
# 04/24/2025 21:29:11 - INFO -     <<< slice_framepos: 5
# 04/24/2025 21:29:11 - INFO -     <<< task_type: retrieval
# 04/24/2025 21:29:11 - INFO -     <<< text_num_hidden_layers: 12
# 04/24/2025 21:29:11 - INFO -     <<< train_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_train.subset.csv
# 04/24/2025 21:29:11 - INFO -     <<< train_frame_order: 0
# 04/24/2025 21:29:11 - INFO -     <<< use_mil: False
# 04/24/2025 21:29:11 - INFO -     <<< val_csv: /content/drive/MyDrive/Data/msrvtt_data/MSRVTT_JSFUSION_test.csv
# 04/24/2025 21:29:11 - INFO -     <<< video_dim: 1024
# 04/24/2025 21:29:11 - INFO -     <<< visual_num_hidden_layers: 12
# 04/24/2025 21:29:11 - INFO -     <<< warmup_proportion: 0.1
# 04/24/2025 21:29:11 - INFO -     <<< world_size: 1
# 04/24/2025 21:29:11 - INFO -   device: cuda n_gpu: 1
# 04/24/2025 21:29:12 - INFO -   loading archive file /content/CLIP_video/modules/cross-base
# 04/24/2025 21:29:12 - INFO -   Model config {
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 512,
#   "initializer_range": 0.02,
#   "intermediate_size": 2048,
#   "max_position_embeddings": 128,
#   "num_attention_heads": 8,
#   "num_hidden_layers": 4,
#   "type_vocab_size": 2,
#   "vocab_size": 512
# }
#
# 04/24/2025 21:29:12 - INFO -   Weight doesn't exsits. /content/CLIP_video/modules/cross-base/cross_pytorch_model.bin
# 04/24/2025 21:29:12 - WARNING -   Stage-One:True, Stage-Two:False
# 04/24/2025 21:29:12 - WARNING -   Test retrieval by loose type.
# 04/24/2025 21:29:12 - WARNING -   	 embed_dim: 512
# 04/24/2025 21:29:12 - WARNING -   	 image_resolution: 224
# 04/24/2025 21:29:12 - WARNING -   	 vision_layers: 12
# 04/24/2025 21:29:12 - WARNING -   	 vision_width: 768
# 04/24/2025 21:29:12 - WARNING -   	 vision_patch_size: 32
# 04/24/2025 21:29:12 - WARNING -   	 context_length: 77
# 04/24/2025 21:29:12 - WARNING -   	 vocab_size: 49408
# 04/24/2025 21:29:12 - WARNING -   	 transformer_width: 512
# 04/24/2025 21:29:12 - WARNING -   	 transformer_heads: 8
# 04/24/2025 21:29:12 - WARNING -   	 transformer_layers: 12
# 04/24/2025 21:29:12 - WARNING -   		 linear_patch: 2d
# 04/24/2025 21:29:12 - WARNING -   	 cut_top_layer: 0
# 04/24/2025 21:29:13 - WARNING -   	 sim_header: meanP
# 04/24/2025 21:29:17 - INFO -   --------------------
# 04/24/2025 21:29:17 - INFO -   Weights from pretrained model not used in CLIP4Clip:
#    clip.input_resolution
#    clip.context_length
#    clip.vocab_size
# 04/24/2025 21:29:18 - INFO -   ***** Running test *****
# 04/24/2025 21:29:18 - INFO -     Num examples = 1000
# 04/24/2025 21:29:18 - INFO -     Batch size = 8
# 04/24/2025 21:29:18 - INFO -     Num steps = 125
# 04/24/2025 21:29:18 - INFO -   ***** Running val *****
# 04/24/2025 21:29:18 - INFO -     Num examples = 1000
# 04/24/2025 21:29:23 - INFO -   ***** Running training *****
# 04/24/2025 21:29:23 - INFO -     Num examples = 18000
# 04/24/2025 21:29:23 - INFO -     Batch size = 64
# 04/24/2025 21:29:23 - INFO -     Num steps = 1405
# Epoch 1:  35% 99/281 [09:14<18:27,  6.09s/it, loss=0.744]04/24/2025 21:38:37 - INFO -   Epoch: 1/5, Step: 100/281, Lr: , Loss: 0.744218, Time/step: 5.542802
# Epoch 1:  71% 199/281 [16:18<02:31,  1.85s/it, loss=0.558]04/24/2025 21:45:41 - INFO -   Epoch: 1/5, Step: 200/281, Lr: , Loss: 0.557591, Time/step: 4.239537
# Epoch 1: 100% 281/281 [21:48<00:00,  4.66s/it, loss=0.587]
# 04/24/2025 21:51:12 - INFO -   Epoch 1/5 Finished, Train Loss: 0.934817
# 04/24/2025 21:51:13 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0
# 04/24/2025 21:51:13 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.0
# Evaluating: 100% 125/125 [02:24<00:00,  1.16s/it]
# 04/24/2025 21:53:43 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 21:53:43 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 21:53:43 - INFO -   Text-to-Video:
# 04/24/2025 21:53:43 - INFO -   	>>>  R@1: 37.6 - R@5: 63.8 - R@10: 75.1 - Median R: 3.0 - Mean R: 19.1
# 04/24/2025 21:53:43 - INFO -   Video-to-Text:
# 04/24/2025 21:53:43 - INFO -   	>>>  V2T$R@1: 37.9 - V2T$R@5: 64.3 - V2T$R@10: 75.2 - V2T$Median R: 3.0 - V2T$Mean R: 16.2
# 04/24/2025 21:53:43 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.6000
# Epoch 2:   6% 18/281 [01:43<30:01,  6.85s/it, loss=0.572]04/24/2025 21:55:27 - INFO -   Epoch: 2/5, Step: 19/281, Lr: , Loss: 0.572435, Time/step: 1.040263
# Epoch 2:  42% 118/281 [08:49<06:31,  2.40s/it, loss=0.671]04/24/2025 22:02:33 - INFO -   Epoch: 2/5, Step: 119/281, Lr: , Loss: 0.670967, Time/step: 4.255368
# Epoch 2:  78% 218/281 [16:15<06:10,  5.87s/it, loss=0.45] 04/24/2025 22:09:59 - INFO -   Epoch: 2/5, Step: 219/281, Lr: , Loss: 0.449793, Time/step: 4.463356
# Epoch 2: 100% 281/281 [20:20<00:00,  4.34s/it, loss=0.551]
# 04/24/2025 22:14:04 - INFO -   Epoch 2/5 Finished, Train Loss: 0.510126
# 04/24/2025 22:14:05 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.1
# 04/24/2025 22:14:05 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.1
# Evaluating: 100% 125/125 [01:12<00:00,  1.72it/s]
# 04/24/2025 22:15:24 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 22:15:24 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 22:15:24 - INFO -   Text-to-Video:
# 04/24/2025 22:15:24 - INFO -   	>>>  R@1: 37.4 - R@5: 63.2 - R@10: 74.9 - Median R: 3.0 - Mean R: 19.9
# 04/24/2025 22:15:24 - INFO -   Video-to-Text:
# 04/24/2025 22:15:24 - INFO -   	>>>  V2T$R@1: 38.2 - V2T$R@5: 65.1 - V2T$R@10: 76.4 - V2T$Median R: 3.0 - V2T$Mean R: 16.3
# 04/24/2025 22:15:24 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.6000
# Epoch 3:  13% 37/281 [03:02<13:36,  3.35s/it, loss=0.229]04/24/2025 22:18:27 - INFO -   Epoch: 3/5, Step: 38/281, Lr: , Loss: 0.229434, Time/step: 1.826741
# Epoch 3:  49% 137/281 [10:28<12:44,  5.31s/it, loss=0.337]04/24/2025 22:25:53 - INFO -   Epoch: 3/5, Step: 138/281, Lr: , Loss: 0.337031, Time/step: 4.457977
# Epoch 3:  84% 237/281 [17:32<03:24,  4.66s/it, loss=0.266]04/24/2025 22:32:57 - INFO -   Epoch: 3/5, Step: 238/281, Lr: , Loss: 0.266395, Time/step: 4.246510
# Epoch 3: 100% 281/281 [20:21<00:00,  4.35s/it, loss=0.317]
# 04/24/2025 22:35:46 - INFO -   Epoch 3/5 Finished, Train Loss: 0.344793
# 04/24/2025 22:35:46 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.2
# 04/24/2025 22:35:46 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.2
# Evaluating: 100% 125/125 [01:11<00:00,  1.74it/s]
# 04/24/2025 22:37:05 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 22:37:05 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 22:37:05 - INFO -   Text-to-Video:
# 04/24/2025 22:37:05 - INFO -   	>>>  R@1: 36.0 - R@5: 63.3 - R@10: 75.3 - Median R: 3.0 - Mean R: 21.0
# 04/24/2025 22:37:05 - INFO -   Video-to-Text:
# 04/24/2025 22:37:05 - INFO -   	>>>  V2T$R@1: 36.1 - V2T$R@5: 63.3 - V2T$R@10: 75.1 - V2T$Median R: 3.0 - V2T$Mean R: 16.7
# 04/24/2025 22:37:05 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.6000
# Epoch 4:  20% 56/281 [04:47<06:16,  1.67s/it, loss=0.197]04/24/2025 22:41:53 - INFO -   Epoch: 4/5, Step: 57/281, Lr: , Loss: 0.197313, Time/step: 2.879793
# Epoch 4:  56% 156/281 [11:51<07:50,  3.76s/it, loss=0.18]04/24/2025 22:48:56 - INFO -   Epoch: 4/5, Step: 157/281, Lr: , Loss: 0.179886, Time/step: 4.231936
# Epoch 4:  91% 256/281 [19:13<00:41,  1.66s/it, loss=0.252]04/24/2025 22:56:18 - INFO -   Epoch: 4/5, Step: 257/281, Lr: , Loss: 0.251665, Time/step: 4.424892
# Epoch 4: 100% 281/281 [20:22<00:00,  4.35s/it, loss=0.354]
# 04/24/2025 22:57:27 - INFO -   Epoch 4/5 Finished, Train Loss: 0.282656
# 04/24/2025 22:57:28 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.3
# 04/24/2025 22:57:28 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.3
# Evaluating: 100% 125/125 [01:11<00:00,  1.75it/s]
# 04/24/2025 22:58:46 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 22:58:46 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 22:58:46 - INFO -   Text-to-Video:
# 04/24/2025 22:58:46 - INFO -   	>>>  R@1: 36.6 - R@5: 63.7 - R@10: 74.9 - Median R: 3.0 - Mean R: 21.4
# 04/24/2025 22:58:46 - INFO -   Video-to-Text:
# 04/24/2025 22:58:46 - INFO -   	>>>  V2T$R@1: 35.9 - V2T$R@5: 63.9 - V2T$R@10: 73.4 - V2T$Median R: 3.0 - V2T$Mean R: 17.4
# 04/24/2025 22:58:46 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.6000
# Epoch 5:  27% 75/281 [05:55<20:28,  5.96s/it, loss=0.203]04/24/2025 23:04:41 - INFO -   Epoch: 5/5, Step: 76/281, Lr: , Loss: 0.203078, Time/step: 3.552538
# Epoch 5:  62% 175/281 [13:02<04:34,  2.59s/it, loss=0.25] 04/24/2025 23:11:49 - INFO -   Epoch: 5/5, Step: 176/281, Lr: , Loss: 0.249829, Time/step: 4.277240
# Epoch 5:  98% 275/281 [20:15<00:32,  5.34s/it, loss=0.205]04/24/2025 23:19:02 - INFO -   Epoch: 5/5, Step: 276/281, Lr: , Loss: 0.205472, Time/step: 4.325980
# Epoch 5: 100% 281/281 [20:19<00:00,  4.34s/it, loss=0.179]
# 04/24/2025 23:19:06 - INFO -   Epoch 5/5 Finished, Train Loss: 0.258958
# 04/24/2025 23:19:07 - INFO -   Model saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.4
# 04/24/2025 23:19:07 - INFO -   Optimizer saved to /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_opt.bin.4
# Evaluating: 100% 125/125 [01:12<00:00,  1.73it/s]
# 04/24/2025 23:20:25 - INFO -   sim matrix size: 1000, 1000
# 04/24/2025 23:20:25 - INFO -   	 Length-T: 1000, Length-V:1000
# 04/24/2025 23:20:25 - INFO -   Text-to-Video:
# 04/24/2025 23:20:25 - INFO -   	>>>  R@1: 36.7 - R@5: 63.4 - R@10: 74.8 - Median R: 3.0 - Mean R: 21.8
# 04/24/2025 23:20:25 - INFO -   Video-to-Text:
# 04/24/2025 23:20:25 - INFO -   	>>>  V2T$R@1: 36.0 - V2T$R@5: 63.8 - V2T$R@10: 73.4 - V2T$Median R: 3.0 - V2T$Mean R: 17.4
# 04/24/2025 23:20:25 - INFO -   The best model is: /content/CLIP_video/ckpts/ckpt_msrvtt_retrieval_looseType/pytorch_model.bin.0, the R1 is: 37.6000
